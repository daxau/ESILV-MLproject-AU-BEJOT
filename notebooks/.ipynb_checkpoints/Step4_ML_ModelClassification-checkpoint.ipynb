# %% [raw]
# # ===============================================================
# # MACHINE LEARNING PROJECT - 2025 GUIDELINES COMPLIANT
# # Title: Stock Price Direction Forecasting using Macroeconomic Indicators
# # Author: Dax AU & Teofil BEJOT
# # ===============================================================
#
# # Stock Price Direction Forecasting using Macroeconomic Indicators
# # -To predict whether a stock’s next-day return will be positive or negative, based on historical returns and macro-economic variables.
#
# # Predicting Apple Stock Direction — Full ML Pipeline
# # This notebook covers these sequential steps:
# 5) Train/test split
# 6) Train models
# 7) Hyperparameter tuning
# 8) Evaluate metrics & compare models

# %%
# ===============================================================
# 1) IMPORT LIBRARIES
# ===============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report, RocCurveDisplay
import shap
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
# ===============================================================
# 1) LOAD DATASETS
# ===============================================================

from pathlib import Path
OUT = Path("../data")
print(OUT)

data = pd.read_csv(OUT / 'Cleaned_Features_for_ML.csv', index_col=0, parse_dates=True)

DATASET_LABEL = "Cleaned_Features_for_ML"
# Out:
# ..\data

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4085 entries, 2010-03-15 to 2025-11-26
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S&P500                             4085 non-null   float64
#  1   NASDAQ                             4085 non-null   float64
#  2   DowJones                           4085 non-null   float64
#  3   CAC40                              4085 non-null   float64
#  4   DAX                                4085 non-null   float64
#  5   FTSE100                            4085 non-null   float64
#  6   Nikkei225                          4085 non-null   float64
#  7   HangSeng                           4085 non-null   float64
#  8   MSCIWorld                          4085 non-null   float64
#  9   US10Y                              4085 non-null   float64
#  10  US2Y                               4085 non-null   float64
#  11  TLT                                4085 non-null   float64
#  12  IEF                                4085 non-null   float64
#  13  BND                                4085 non-null   float64
#  14  LQD                                4085 non-null   float64
#  15  Apple                              4085 non-null   float64
#  16  Microsoft                          4085 non-null   float64
#  17  Google                             4085 non-null   float64
#  18  Amazon                             4085 non-null   float64
#  19  Meta                               4085 non-null   float64
#  20  Inflation_CPI                      4085 non-null   float64
#  21  Unemployment_Rate                  4085 non-null   float64
#  22  Fed_Funds_Rate                     4085 non-null   float64
#  23  Real_GDP                           4085 non-null   float64
#  24  Yield_Curve_Spread                 4085 non-null   float64
#  25  Industrial_Production              4085 non-null   float64
#  26  M2_Money_Supply                    4085 non-null   float64
#  27  Personal_Consumption_Expenditures  4085 non-null   float64
#  28  Recession_Probability              4085 non-null   float64
#  29  GDP_Current_USD                    4085 non-null   float64
#  30  Inflation_Annual_Pct               4085 non-null   float64
#  31  Unemployment_Total_Pct             4085 non-null   float64
#  32  Exports_GDP_Pct                    4085 non-null   float64
#  33  Imports_GDP_Pct                    4085 non-null   float64
#  34  Public_Debt_GDP_Pct                4085 non-null   float64
#  35  OECD_CPI_2015idx_USA               4085 non-null   float64
#  36  OECD_Unemp_rate_pct_USA            4085 non-null   float64
#  37  Return                             4085 non-null   float64
#  38  Volatility_20d                     4085 non-null   float64
#  39  MA20                               4085 non-null   float64
#  40  MA50                               4085 non-null   float64
#  41  Momentum                           4085 non-null   float64
#  42  RSI                                4085 non-null   float64
#  43  Direction                          4085 non-null   int64
# dtypes: float64(43), int64(1)
# memory usage: 1.4 MB
# None

# %%
print(data.tail(10))
# Out:
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2025-11-13 -1.800835 -2.012372 -1.911938 -0.116626 -1.286203 -1.206402
# 2025-11-14 -0.103218  0.060807 -0.783549 -0.700174 -0.652426 -1.283454
# 2025-11-17 -1.018955 -0.771737 -1.380607 -0.581197 -1.110661 -0.291682
# 2025-11-18 -0.923176 -1.089503 -1.254317 -1.687635 -1.594544 -1.461936
# 2025-11-19  0.346751  0.448883  0.067861 -0.180675 -0.105241 -0.554962
# 2025-11-20 -1.696201 -1.896199 -0.992297  0.285718  0.411328  0.217805
# 2025-11-21  0.988488  0.703647  1.168726 -0.003846 -0.756935  0.118809
# 2025-11-24  1.585285  2.248886  0.447614 -0.279299  0.534485 -0.080458
# 2025-11-25  0.907986  0.522320  1.565905  0.722240  0.832171  0.860920
# 2025-11-26  0.680125  0.650499  0.706248  0.766315  0.961830  0.942057
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2025-11-13   0.325568  0.459781  -1.912619  0.494968  ...
# 2025-11-14  -1.542883 -1.576786  -0.074963  0.371641  ...
# 2025-11-17  -0.127978 -0.611663  -1.251536 -0.171828  ...
# 2025-11-18  -2.782957 -1.469099  -1.009869 -0.119256  ...
# 2025-11-19  -0.328098 -0.336768   0.136123  0.093583  ...
# 2025-11-20   2.218530  0.003592  -1.816517 -0.299957  ...
# 2025-11-21  -2.087465 -2.028239   1.172335 -0.473029  ...
# 2025-11-24   0.019944  1.652962   1.223852 -0.283278  ...
# 2025-11-25  -0.038993  0.573233   1.260821 -0.404626  ...
# 2025-11-26   1.535884  0.097025   0.900092 -0.056874  ...
#
#             Public_Debt_GDP_Pct  OECD_CPI_2015idx_USA  \
# Date
# 2025-11-13             1.029674               2.08743
# 2025-11-14             1.029674               2.08743
# 2025-11-17             1.029674               2.08743
# 2025-11-18             1.029674               2.08743
# 2025-11-19             1.029674               2.08743
# 2025-11-20             1.029674               2.08743
# 2025-11-21             1.029674               2.08743
# 2025-11-24             1.029674               2.08743
# 2025-11-25             1.029674               2.08743
# 2025-11-26             1.029674               2.08743
#
#             OECD_Unemp_rate_pct_USA    Return  Volatility_20d      MA20  \
# Date
# 2025-11-13                -0.641084 -0.184052       -0.490210  1.108618
# 2025-11-14                -0.641084 -0.188882       -0.550240  0.807357
# 2025-11-17                -0.641084 -1.205167       -0.888984  0.001538
# 2025-11-18                -0.641084 -0.069404       -0.888888 -0.027776
# 2025-11-19                -0.641084  0.198122       -1.020821  0.260758
# 2025-11-20                -0.641084 -0.604553       -0.978167  0.079291
# 2025-11-21                -0.641084  1.170480       -0.891470  0.179985
# 2025-11-24                -0.641084  0.959396       -0.988282  0.089434
# 2025-11-25                -0.641084  0.174120       -0.986204  0.132775
# 2025-11-26                -0.641084  0.066712       -0.986556  0.125666
#
#                 MA50  Momentum       RSI  Direction
# Date
# 2025-11-13  0.721742  0.229995 -1.160129          0
# 2025-11-14  0.707638  0.065308 -2.203318          0
# 2025-11-17  0.614207 -0.676792 -1.763633          0
# 2025-11-18  0.744104 -0.004434 -0.189950          1
# 2025-11-19  1.064761 -0.112939 -0.142656          0
# 2025-11-20  0.863399  0.758166 -0.356219          1
# 2025-11-21  0.882030 -1.679574  1.668407          1
# 2025-11-24  0.926737 -0.155119  0.902886          1
# 2025-11-25  0.906321 -4.813854  0.254893          1
# 2025-11-26  0.893712  0.080380  0.256799          0
#
# [10 rows x 44 columns]

# %%
# ===============================================================
#  SAVE RESULTS HELPERS (JSON + CSV EXPORT) Required for the Dashboard
# ===============================================================
from pathlib import Path
import json
import numpy as np
import pandas as pd

# ===============================================================
# Define output folder inside project: /data
# ===============================================================

OUT = Path("../data")   # <-- for notebooks located inside /notebooks/
OUT.mkdir(parents=True, exist_ok=True)

def make_json_serializable(obj):
    """
    Recursively convert objects (numpy arrays, numpy numbers, dicts, lists)
    into JSON-serializable Python native types.
    """
    if isinstance(obj, dict):
        return {k: make_json_serializable(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [make_json_serializable(i) for i in obj]
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, (np.integer, np.int64, np.int32)):
        return int(obj)
    elif isinstance(obj, (np.floating, np.float32, np.float64)):
        return float(obj)
    elif isinstance(obj, (np.bool_, bool)):
        return bool(obj)
    else:
        return obj

# ===============================================================
# JSON + CSV Saving Utilities
# ===============================================================

def save_results_to_json(results_dict, filename="model_results.json"):
    """Save the entire results dictionary into /data as JSON."""
    results_serializable = make_json_serializable(results_dict)
    filepath = OUT / filename

    with open(filepath, "w") as f:
        json.dump(results_serializable, f, indent=4)

    print(f"[INFO] Saved JSON to: {filepath.resolve()}")


def save_results_to_csv(results_dict, filename="model_results.csv"):
    """Flatten model metrics into tabular CSV saved under /data."""
    rows = []

    for model_name, res in results_dict.items():
        cm = np.array(res.get("confusion_matrix"))
        cr = res.get("classification_report", {})
        roc_auc = res.get("roc_auc", None)
        f2 = res.get("f2_score", None)
        comp_time = res.get("computation_time_sec", None)

        # Accuracy
        acc = cr.get("accuracy", None)

        # Positive class key
        pos_key = "1" if "1" in cr else None
        if not pos_key:
            keys = [k for k in cr.keys() if k.isdigit()]
            if keys:
                pos_key = keys[-1]

        precision_1 = recall_1 = f1_1 = None
        if pos_key and isinstance(cr.get(pos_key), dict):
            precision_1 = cr[pos_key].get("precision")
            recall_1 = cr[pos_key].get("recall")
            f1_1 = cr[pos_key].get("f1-score")

        # Confusion matrix extract
        tn = fp = fn = tp = None
        if cm.shape == (2, 2):
            tn, fp, fn, tp = cm.ravel()

        rows.append({
            "Dataset": res.get("dataset_label", "Unknown"),   # <--- added
            "Model": model_name,
            "Accuracy": acc,
            "Precision (class 1)": precision_1,
            "Recall (class 1)": recall_1,
            "F1-score (class 1)": f1_1,
            "F2-score": f2,
            "ROC-AUC": roc_auc,
            "Computation Time (sec)": comp_time,
            "TN": tn,
            "FP": fp,
            "FN": fn,
            "TP": tp,
        })

    df = pd.DataFrame(rows)

    filepath = OUT / filename
    df.to_csv(filepath, index=False)

    print(f"[INFO] Saved CSV to: {filepath.resolve()}")


# GLOBAL CONTAINER
results = {}

# %% [raw]
# Results Export Utilities (JSON + CSV)
# This section provides helper functions used to export model evaluation results:
#
# make_json_serializable()
# Converts NumPy objects, arrays, floats, integers, and booleans into native Python types so they can be stored as valid JSON.
#
# save_results_to_json()
# Saves the full results dictionary (metrics, confusion matrices, reports, timings, etc.) into a structured JSON file inside the /data directory.
#
# save_results_to_csv()
# Flattens model metrics into a tabular format appropriate for CSV export.
# Extracts:
# - Accuracy, precision, recall, F1-score, F2-score
# - ROC-AUC
# - Confusion matrix elements (TN, FP, FN, TP)
# - Computation time
# - Dataset label (if provided)
# - Both functions ensure consistent reproducible exports for later analysis, comparison, or integration with dashboards and reporting tools.

# %%
def save_results(model_name, y_true, y_pred, y_prob=None, comp_time=None):
    from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, fbeta_score

    results[model_name] = {}

    cm = confusion_matrix(y_true, y_pred)
    results[model_name]["confusion_matrix"] = cm

    report = classification_report(y_true, y_pred, output_dict=True)
    results[model_name]["classification_report"] = report

    if y_prob is not None:
        results[model_name]["roc_auc"] = roc_auc_score(y_true, y_prob)

    results[model_name]["f2_score"] = fbeta_score(y_true, y_pred, beta=2)

    results[model_name]["computation_time_sec"] = comp_time

    print(f"Saved model results for: {model_name}")

# %% [raw]
# Saving Model Evaluation Results
# The save_results() function stores all evaluation metrics for a given model in the global results dictionary.
# This makes it easy to collect, aggregate, export, and compare performance across different algorithms.
#
# Saved information includes:
# - Confusion matrix
# Captures true positives, false positives, false negatives, and true negatives.
# - Classification report
# Provides precision, recall, F1-score, and accuracy for each class.
# - ROC-AUC score
# Computed when probability predictions are available.
# - F2-score
# A recall-oriented metric useful when false negatives are more costly.
# - Computation time
# Tracks model runtime for performance profiling.
#
# These saved metrics are later used by the JSON and CSV export utilities for structured reporting and model comparison.

# %%
# ---------------------------------------------------------------
# IMPORTS
# ---------------------------------------------------------------
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, RobustScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import (
    AdaBoostClassifier, GradientBoostingClassifier,
    RandomForestClassifier, ExtraTreesClassifier
)

# ===============================================================
# TRAIN / TEST SPLIT
# ===============================================================
features = data.drop(columns=['Apple', 'Return', 'Direction'])
target = data["Direction"] 

features.replace([np.inf, -np.inf], np.nan, inplace=True)

X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.2, shuffle=False
)
print(f"Train shape: {X_train.shape} | Test shape: {X_test.shape}")

# ===============================================================
# FEATURE TYPES
# ===============================================================
numeric_features = X_train.select_dtypes(include=[np.number]).columns
categorical_features = X_train.select_dtypes(exclude=[np.number]).columns

print(f"Numeric features: {len(numeric_features)} | Categorical features: {len(categorical_features)}")

# ===============================================================
# PREPROCESSING PIPELINES
# ===============================================================
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# Combine preprocessing
preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# ===============================================================
# DEFINE MODELS
# ===============================================================
models = [
    ('LR',  LogisticRegression(max_iter=5000, random_state=42)),
    ('KNN', KNeighborsClassifier(n_neighbors=5)),
    ('CART', DecisionTreeClassifier(max_depth=6, random_state=42)),
    ('SVC', SVC(kernel='rbf', probability=True, random_state=42)),
    ('MLP', MLPClassifier(hidden_layer_sizes=(64, 32), max_iter=5000, random_state=42)),
    ('ABR', AdaBoostClassifier(n_estimators=300, random_state=42)),
    ('GBR', GradientBoostingClassifier(n_estimators=300, random_state=42)),
    ('RFR', RandomForestClassifier(n_estimators=300, random_state=42)),
    ('ETR', ExtraTreesClassifier(n_estimators=300, random_state=42))
]

# ===============================================================
# BINARY CLASSIFICATION — MODEL EVALUATION (Production Format)
# Output Table = [Model | Accuracy | F1 | AUC | F2 | Time]
# ===============================================================

from time import time
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score,
    confusion_matrix, classification_report, fbeta_score
)

results = {}    
rows_for_display = []   

for name, model in models:

    pipe = Pipeline([
        ("preprocessor", preprocessor),
        ("clf", model)
    ])

    t0 = time()
    pipe.fit(X_train, y_train)

    y_pred = pipe.predict(X_test)

    # Probabilities for AUC
    if hasattr(pipe.named_steps["clf"], "predict_proba"):
        y_prob = pipe.predict_proba(X_test)[:, 1]
    else:
        y_prob = np.zeros_like(y_pred)

    # ---- Compute Metrics ----
    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred)
    f2  = fbeta_score(y_test, y_pred, beta=2)
    auc = roc_auc_score(y_test, y_prob)
    comp_time = time() - t0

    # Confusion matrix + full report
    cm     = confusion_matrix(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)

    results[name] = {
        "dataset_label": DATASET_LABEL,
        "test_accuracy": float(acc),
        "roc_auc": float(auc),
        "f1_score": float(f1),
        "f2_score": float(f2),
        "computation_time_sec": float(comp_time),
        "confusion_matrix": cm.tolist(),
        "classification_report": report
    }

    rows_for_display.append([
        name, acc, f1, auc, f2, comp_time
    ])

# ===============================================================
# FINAL SUMMARY TABLE
# ===============================================================

df_results = pd.DataFrame(
    rows_for_display,
    columns=["Model", "Accuracy", "F1-score", "AUC", "F2-score", "Time (sec)"]
)

df_results = df_results.sort_values("AUC", ascending=False).reset_index(drop=True)

display(df_results.style.background_gradient(cmap="Blues"))
# Out:
# Train shape: (3268, 41) | Test shape: (817, 41)
# Numeric features: 41 | Categorical features: 0
# <style type="text/css">
# #T_ab75c_row0_col1, #T_ab75c_row0_col3, #T_ab75c_row4_col1, #T_ab75c_row4_col5, #T_ab75c_row7_col2, #T_ab75c_row7_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ab75c_row0_col2, #T_ab75c_row0_col4, #T_ab75c_row1_col5, #T_ab75c_row8_col1, #T_ab75c_row8_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ab75c_row0_col5 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_ab75c_row1_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_ab75c_row1_col2, #T_ab75c_row5_col4 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_ab75c_row1_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_ab75c_row1_col4 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_ab75c_row2_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_ab75c_row2_col2 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_ab75c_row2_col3 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_ab75c_row2_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_ab75c_row2_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ab75c_row3_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_ab75c_row3_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_ab75c_row3_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_ab75c_row3_col4 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_ab75c_row3_col5 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_ab75c_row4_col2 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_ab75c_row4_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_ab75c_row4_col4 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_ab75c_row5_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_ab75c_row5_col2 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_ab75c_row5_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_ab75c_row5_col5 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_ab75c_row6_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_ab75c_row6_col2, #T_ab75c_row6_col4 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_ab75c_row6_col3 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_ab75c_row6_col5 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_ab75c_row7_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_ab75c_row7_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_ab75c_row7_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_ab75c_row8_col2 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_ab75c_row8_col4 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_ab75c_row8_col5 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab75c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab75c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ab75c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ab75c_level0_col2" class="col_heading level0 col2" >F1-score</th>
#       <th id="T_ab75c_level0_col3" class="col_heading level0 col3" >AUC</th>
#       <th id="T_ab75c_level0_col4" class="col_heading level0 col4" >F2-score</th>
#       <th id="T_ab75c_level0_col5" class="col_heading level0 col5" >Time (sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab75c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab75c_row0_col0" class="data row0 col0" >MLP</td>
#       <td id="T_ab75c_row0_col1" class="data row0 col1" >0.525092</td>
#       <td id="T_ab75c_row0_col2" class="data row0 col2" >0.382166</td>
#       <td id="T_ab75c_row0_col3" class="data row0 col3" >0.528283</td>
#       <td id="T_ab75c_row0_col4" class="data row0 col4" >0.314301</td>
#       <td id="T_ab75c_row0_col5" class="data row0 col5" >6.862926</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab75c_row1_col0" class="data row1 col0" >CART</td>
#       <td id="T_ab75c_row1_col1" class="data row1 col1" >0.511628</td>
#       <td id="T_ab75c_row1_col2" class="data row1 col2" >0.544000</td>
#       <td id="T_ab75c_row1_col3" class="data row1 col3" >0.521531</td>
#       <td id="T_ab75c_row1_col4" class="data row1 col4" >0.551948</td>
#       <td id="T_ab75c_row1_col5" class="data row1 col5" >0.107433</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab75c_row2_col0" class="data row2 col0" >LR</td>
#       <td id="T_ab75c_row2_col1" class="data row2 col1" >0.523868</td>
#       <td id="T_ab75c_row2_col2" class="data row2 col2" >0.647964</td>
#       <td id="T_ab75c_row2_col3" class="data row2 col3" >0.513817</td>
#       <td id="T_ab75c_row2_col4" class="data row2 col4" >0.750210</td>
#       <td id="T_ab75c_row2_col5" class="data row2 col5" >0.299924</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ab75c_row3_col0" class="data row3 col0" >KNN</td>
#       <td id="T_ab75c_row3_col1" class="data row3 col1" >0.495716</td>
#       <td id="T_ab75c_row3_col2" class="data row3 col2" >0.527523</td>
#       <td id="T_ab75c_row3_col3" class="data row3 col3" >0.505140</td>
#       <td id="T_ab75c_row3_col4" class="data row3 col4" >0.534138</td>
#       <td id="T_ab75c_row3_col5" class="data row3 col5" >0.909728</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ab75c_row4_col0" class="data row4 col0" >GBR</td>
#       <td id="T_ab75c_row4_col1" class="data row4 col1" >0.525092</td>
#       <td id="T_ab75c_row4_col2" class="data row4 col2" >0.656637</td>
#       <td id="T_ab75c_row4_col3" class="data row4 col3" >0.504408</td>
#       <td id="T_ab75c_row4_col4" class="data row4 col4" >0.769390</td>
#       <td id="T_ab75c_row4_col5" class="data row4 col5" >8.829043</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ab75c_row5_col0" class="data row5 col0" >ETR</td>
#       <td id="T_ab75c_row5_col1" class="data row5 col1" >0.510404</td>
#       <td id="T_ab75c_row5_col2" class="data row5 col2" >0.568966</td>
#       <td id="T_ab75c_row5_col3" class="data row5 col3" >0.503483</td>
#       <td id="T_ab75c_row5_col4" class="data row5 col4" >0.597555</td>
#       <td id="T_ab75c_row5_col5" class="data row5 col5" >1.707054</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ab75c_row6_col0" class="data row6 col0" >ABR</td>
#       <td id="T_ab75c_row6_col1" class="data row6 col1" >0.509180</td>
#       <td id="T_ab75c_row6_col2" class="data row6 col2" >0.670501</td>
#       <td id="T_ab75c_row6_col3" class="data row6 col3" >0.500426</td>
#       <td id="T_ab75c_row6_col4" class="data row6 col4" >0.816653</td>
#       <td id="T_ab75c_row6_col5" class="data row6 col5" >3.818708</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ab75c_row7_col0" class="data row7 col0" >SVC</td>
#       <td id="T_ab75c_row7_col1" class="data row7 col1" >0.522644</td>
#       <td id="T_ab75c_row7_col2" class="data row7 col2" >0.686495</td>
#       <td id="T_ab75c_row7_col3" class="data row7 col3" >0.494701</td>
#       <td id="T_ab75c_row7_col4" class="data row7 col4" >0.845545</td>
#       <td id="T_ab75c_row7_col5" class="data row7 col5" >3.262937</td>
#     </tr>
#     <tr>
#       <th id="T_ab75c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ab75c_row8_col0" class="data row8 col0" >RFR</td>
#       <td id="T_ab75c_row8_col1" class="data row8 col1" >0.482252</td>
#       <td id="T_ab75c_row8_col2" class="data row8 col2" >0.493413</td>
#       <td id="T_ab75c_row8_col3" class="data row8 col3" >0.482877</td>
#       <td id="T_ab75c_row8_col4" class="data row8 col4" >0.486767</td>
#       <td id="T_ab75c_row8_col5" class="data row8 col5" >4.523082</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# Conclusions
# 1. Overall model performance is weak: All models score around 0.50 AUC, meaning no model captures strong predictive signals in the features.
#
# 2. The best models according to AUC:
# - MLP (0.528)
# - CART (0.522)
# - LR (0.514)
# Gains are minimal and not statistically meaningful.
#
# 3. Models show signs of overfitting:
# High F1 or F2 on some models does NOT translate to higher AUC.
# This indicates they detect noise rather than signal.
#
# 4. Feature set is likely the limiting factor:
# Predicting next-day direction using macro + market features remains extremely difficult.
# Additional engineered features or regime-based approaches are needed.
#
# 5. Current models should NOT be used for trading decisions:
# Predictive power is too close to random guessing.
# AUC ≈ 0.50 = no usable edge.
#
# Final Takeaway
# The dataset in its current form does not contain exploitable information for next-day direction.
# Model improvements will require new features, not new algorithms.

# %%
save_results_to_json(results, "model_results.json")
save_results_to_csv(results, "model_results.csv")
print("✓ All results exported successfully.")
# Out:
# [INFO] Saved JSON to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data\model_results.json
# [INFO] Saved CSV to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data\model_results.csv
# ✓ All results exported successfully.

# %%
# ===============================================================
# ADVANCED MODELS – ENSEMBLE & META-LEARNING COMPARISON
# ===============================================================
print("\n====================================================")
print("   ADVANCED ML MODELS – ENSEMBLE & STACKING")
print("====================================================\n")

import time
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    BaggingClassifier,
    VotingClassifier,
    StackingClassifier
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score, 
    f1_score, 
    roc_auc_score, 
    fbeta_score,
    confusion_matrix,
    classification_report
)

# ===============================================================
# 1) PREPROCESSING PIPELINE
# ===============================================================
def make_pipeline(model):
    return Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
        ("model", model)
    ])

# Base models
base_svm = SVC(kernel='rbf', probability=True, random_state=0)
base_dt  = DecisionTreeClassifier(random_state=0)


# ===============================================================
# 2) TUNED MODELS WITH GRID SEARCH
# ===============================================================

# --- SVM ---
param_svm = {
    "model__C": [0.1, 1, 10],
    "model__gamma": ["scale", 0.01, 0.001]
}

tuned_svm = GridSearchCV(
    make_pipeline(SVC(probability=True, random_state=0)),
    param_svm,
    cv=5,
    n_jobs=-1,
    error_score="raise"
)
tuned_svm.fit(X_train, y_train)

# --- Decision Tree ---
param_dt = {
    "model__max_depth": [3, 5, 7, None],
    "model__min_samples_split": [2, 5, 10]
}

tuned_dt = GridSearchCV(
    make_pipeline(DecisionTreeClassifier(random_state=0)),
    param_dt,
    cv=5,
    n_jobs=-1,
    error_score="raise"
)
tuned_dt.fit(X_train, y_train)


# ===============================================================
# 3) BAGGING MODELS
# ===============================================================

bagging_svm = make_pipeline(
    BaggingClassifier(
        estimator=SVC(kernel='rbf', probability=True),
        n_estimators=20,
        max_samples=0.8,
        random_state=0
    )
)

bagging_dt = make_pipeline(
    BaggingClassifier(
        estimator=DecisionTreeClassifier(),
        n_estimators=50,
        max_samples=0.8,
        random_state=0
    )
)


# ===============================================================
# 4) VOTING CLASSIFIER
# ===============================================================
voting = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
    ("model", VotingClassifier(
        estimators=[
            ('svm', SVC(kernel='rbf', probability=True)),
            ('dt', DecisionTreeClassifier())
        ],
        voting='soft'
    ))
])


# ===============================================================
# 5) STACKING CLASSIFIER
# ===============================================================
stacking = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler()),
    ("model", StackingClassifier(
        estimators=[
            ('svm', SVC(kernel='rbf', probability=True)),
            ('dt', DecisionTreeClassifier()),
            ('bag_svm', BaggingClassifier(
                estimator=SVC(kernel='rbf', probability=True),
                n_estimators=10)),
            ('bag_dt', BaggingClassifier(
                estimator=DecisionTreeClassifier(),
                n_estimators=10))
        ],
        final_estimator=LogisticRegression(max_iter=500),
        passthrough=True,
        n_jobs=-1
    ))
])


# ===============================================================
# 6) MODEL COLLECTION
# ===============================================================
ensemble_models = {
    "Tuned SVM": tuned_svm.best_estimator_,
    "Tuned Decision Tree": tuned_dt.best_estimator_,
    "Bagging SVM": bagging_svm,
    "Bagging Decision Tree": bagging_dt,
    "Voting (SVM + DT)": voting,
    "Stacking Meta-Model": stacking
}


# ===============================================================
# 7) MASTER LOOP — TRAIN + EVALUATE + LOG INTO RESULTS
# ===============================================================
for name, model in ensemble_models.items():

    print(f"\n▶ Training {name} ...")
    start_time = time.time()

    model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_test)
    
    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:, 1]
    else:
        y_prob = np.zeros_like(y_pred)

    # Metrics
    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred)
    f2  = fbeta_score(y_test, y_pred, beta=2)
    auc = roc_auc_score(y_test, y_prob)

    cm = confusion_matrix(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)

    comp_time = time.time() - start_time

    # SAVE to global results
    results[name] = {
        "dataset_label": DATASET_LABEL, 
        "train_accuracy": None,
        "test_accuracy": float(acc),
        "roc_auc": float(auc),
        "f1_score": float(f1),
        "f2_score": float(f2),
        "computation_time_sec": float(comp_time),
        "confusion_matrix": cm.tolist(),
        "classification_report": report
    }

    print(f"""
{name}:
  ACC  = {acc:.4f}
  F1   = {f1:.4f}
  F2   = {f2:.4f}
  AUC  = {auc:.4f}
  Time = {comp_time:.2f} sec
""")


# ===============================================================
# 8) SUMMARY TABLE FOR DISPLAY
# ===============================================================

df_results_ens = pd.DataFrame([
    [
        name,
        results[name]["test_accuracy"],
        results[name]["f1_score"],
        results[name]["roc_auc"],
        results[name]["f2_score"],
        results[name]["computation_time_sec"]
    ]
    for name in ensemble_models.keys()
], columns=["Model", "Accuracy", "F1-score", "AUC", "F2-score", "Time (sec)"])

df_results_ens = df_results_ens.sort_values(by="AUC", ascending=False).reset_index(drop=True)

display(
    df_results_ens.style.background_gradient(
        cmap="Blues",
        subset=["Accuracy", "F1-score", "AUC", "F2-score", "Time (sec)"]
    )
)
# Out:
# ====================================================
#    ADVANCED ML MODELS – ENSEMBLE & STACKING
# ====================================================
#
#
# ▶ Training Tuned SVM ...
#
# Tuned SVM:
#   ACC  = 0.5226
#   F1   = 0.6865
#   F2   = 0.8455
#   AUC  = 0.5042
#   Time = 3.15 sec
#
#
# ▶ Training Tuned Decision Tree ...
#
# Tuned Decision Tree:
#   ACC  = 0.4982
#   F1   = 0.5747
#   F2   = 0.6169
#   AUC  = 0.5121
#   Time = 0.06 sec
#
#
# ▶ Training Bagging SVM ...
#
# Bagging SVM:
#   ACC  = 0.5226
#   F1   = 0.6865
#   F2   = 0.8455
#   AUC  = 0.4974
#   Time = 21.00 sec
#
#
# ▶ Training Bagging Decision Tree ...
#
# Bagging Decision Tree:
#   ACC  = 0.4737
#   F1   = 0.4953
#   F2   = 0.4946
#   AUC  = 0.4819
#   Time = 3.70 sec
#
#
# ▶ Training Voting (SVM + DT) ...
#
# Voting (SVM + DT):
#   ACC  = 0.5006
#   F1   = 0.5072
#   F2   = 0.4979
#   AUC  = 0.4930
#   Time = 3.27 sec
#
#
# ▶ Training Stacking Meta-Model ...
#
# Stacking Meta-Model:
#   ACC  = 0.5153
#   F1   = 0.6243
#   F2   = 0.7045
#   AUC  = 0.5080
#   Time = 25.59 sec
# <style type="text/css">
# #T_3932c_row0_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3932c_row0_col2 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_3932c_row0_col3, #T_3932c_row1_col5, #T_3932c_row2_col1, #T_3932c_row2_col2, #T_3932c_row2_col4, #T_3932c_row3_col1, #T_3932c_row3_col2, #T_3932c_row3_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3932c_row0_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_3932c_row0_col5, #T_3932c_row5_col1, #T_3932c_row5_col2, #T_3932c_row5_col3, #T_3932c_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3932c_row1_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_3932c_row1_col2 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_3932c_row1_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_3932c_row1_col4 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3932c_row2_col3 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_3932c_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_3932c_row3_col3 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_3932c_row3_col5 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_3932c_row4_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_3932c_row4_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_3932c_row4_col3 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_3932c_row4_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3932c_row4_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_3932c_row5_col5 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# </style>
# <table id="T_3932c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3932c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3932c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3932c_level0_col2" class="col_heading level0 col2" >F1-score</th>
#       <th id="T_3932c_level0_col3" class="col_heading level0 col3" >AUC</th>
#       <th id="T_3932c_level0_col4" class="col_heading level0 col4" >F2-score</th>
#       <th id="T_3932c_level0_col5" class="col_heading level0 col5" >Time (sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3932c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3932c_row0_col0" class="data row0 col0" >Tuned Decision Tree</td>
#       <td id="T_3932c_row0_col1" class="data row0 col1" >0.498164</td>
#       <td id="T_3932c_row0_col2" class="data row0 col2" >0.574689</td>
#       <td id="T_3932c_row0_col3" class="data row0 col3" >0.512088</td>
#       <td id="T_3932c_row0_col4" class="data row0 col4" >0.616927</td>
#       <td id="T_3932c_row0_col5" class="data row0 col5" >0.056936</td>
#     </tr>
#     <tr>
#       <th id="T_3932c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3932c_row1_col0" class="data row1 col0" >Stacking Meta-Model</td>
#       <td id="T_3932c_row1_col1" class="data row1 col1" >0.515300</td>
#       <td id="T_3932c_row1_col2" class="data row1 col2" >0.624288</td>
#       <td id="T_3932c_row1_col3" class="data row1 col3" >0.507975</td>
#       <td id="T_3932c_row1_col4" class="data row1 col4" >0.704497</td>
#       <td id="T_3932c_row1_col5" class="data row1 col5" >25.586657</td>
#     </tr>
#     <tr>
#       <th id="T_3932c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3932c_row2_col0" class="data row2 col0" >Tuned SVM</td>
#       <td id="T_3932c_row2_col1" class="data row2 col1" >0.522644</td>
#       <td id="T_3932c_row2_col2" class="data row2 col2" >0.686495</td>
#       <td id="T_3932c_row2_col3" class="data row2 col3" >0.504239</td>
#       <td id="T_3932c_row2_col4" class="data row2 col4" >0.845545</td>
#       <td id="T_3932c_row2_col5" class="data row2 col5" >3.150019</td>
#     </tr>
#     <tr>
#       <th id="T_3932c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3932c_row3_col0" class="data row3 col0" >Bagging SVM</td>
#       <td id="T_3932c_row3_col1" class="data row3 col1" >0.522644</td>
#       <td id="T_3932c_row3_col2" class="data row3 col2" >0.686495</td>
#       <td id="T_3932c_row3_col3" class="data row3 col3" >0.497406</td>
#       <td id="T_3932c_row3_col4" class="data row3 col4" >0.845545</td>
#       <td id="T_3932c_row3_col5" class="data row3 col5" >21.003783</td>
#     </tr>
#     <tr>
#       <th id="T_3932c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3932c_row4_col0" class="data row4 col0" >Voting (SVM + DT)</td>
#       <td id="T_3932c_row4_col1" class="data row4 col1" >0.500612</td>
#       <td id="T_3932c_row4_col2" class="data row4 col2" >0.507246</td>
#       <td id="T_3932c_row4_col3" class="data row4 col3" >0.493040</td>
#       <td id="T_3932c_row4_col4" class="data row4 col4" >0.497866</td>
#       <td id="T_3932c_row4_col5" class="data row4 col5" >3.267901</td>
#     </tr>
#     <tr>
#       <th id="T_3932c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3932c_row5_col0" class="data row5 col0" >Bagging Decision Tree</td>
#       <td id="T_3932c_row5_col1" class="data row5 col1" >0.473684</td>
#       <td id="T_3932c_row5_col2" class="data row5 col2" >0.495305</td>
#       <td id="T_3932c_row5_col3" class="data row5 col3" >0.481892</td>
#       <td id="T_3932c_row5_col4" class="data row5 col4" >0.494609</td>
#       <td id="T_3932c_row5_col5" class="data row5 col5" >3.699213</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# Advanced Models — Ensemble & Stacking (Summary)
# - No ensemble or meta-model beats the classic models.
# - All AUC scores stay around 0.49–0.51 → no predictive signal.
# - Best performer: Stacking Meta-Model, but still ≈0.50 AUC.
# - Tuned models (SVM, Decision Tree) show tiny improvements, not meaningful.
# - Complex methods (Bagging/Stacking) cost more time with no gain.
#
# Conclusion:
# Ensembles do not improve results — the limitation is the dataset, not the models.

# %%
save_results_to_json(results, "model_results.json")
save_results_to_csv(results, "model_results.csv")
print("✓ All results exported successfully.")
# Out:
# [INFO] Saved JSON to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data\model_results.json
# [INFO] Saved CSV to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data\model_results.csv
# ✓ All results exported successfully.

# %%
import matplotlib.pyplot as plt

data_2024_2025 = data.loc['2024-01-01':'2025-12-31']

num_cols = len(data_2024_2025.columns)
n_rows = (num_cols // 3) + (num_cols % 3 > 0)  # 3 plots per row

fig, axes = plt.subplots(n_rows, 3, figsize=(18, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(data_2024_2025.columns):
    if col == 'Apple':
        axes[i].plot(data_2024_2025.index, data_2024_2025[col], color='red')
    else:
        axes[i].plot(data_2024_2025.index, data_2024_2025[col])

    axes[i].set_title(col)
    axes[i].tick_params(axis='x', rotation=45)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Final Conclusions:
#
# - All classical ML models (LR, SVC, GBR, etc.) reach AUC ≈ 0.50, showing no strong predictive signal in daily direction.
# - Ensemble methods improve stability: Stacking and Bagging SVM perform best but still remain close to randomness.
# - Feature time-series (2024–2025) show high noise and weak structure; macro features move too slowly to help.
# - Overall, daily market direction is extremely hard to predict with ML — the data behaves almost like noise.

# %% [raw]
# Summary
#
# The time-series plots show noisy, unstable movements with no clear trend.
# Most features fluctuate randomly; macro indicators stay flat.
# Individual feature plots confirm no visual pattern linked to Direction.
# Pairplots show full overlap between classes → no separation.
# ANOVA F-test identifies weak features, none strongly predictive.
# All ML models (classic + ensemble) score ~0.50 accuracy and AUC.
# No algorithm extracts meaningful signal.
# Conclusion: the dataset behaves like noise → daily direction is not predictable.
