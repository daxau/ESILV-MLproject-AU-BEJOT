# %% [raw]
# # ===============================================================
# # MACHINE LEARNING PROJECT - 2025 GUIDELINES COMPLIANT
# # Title: Stock Price Direction Forecasting using Macroeconomic Indicators
# # Author: Dax AU / Téofil BEJOT
# # ===============================================================
#
# # Stock Price Direction Forecasting using Macroeconomic Indicators
# # -To predict whether a stock’s next-day return will be positive or negative, based on historical returns and macro-economic variables.
#
# # Predicting Apple Stock Direction — Full ML Pipeline
# # This notebook covers this single step:
# 3) Data exploration & preprocessing to generate the clean dataset for model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report, RocCurveDisplay
import shap
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
# ===============================================================
# 1) LOAD DATASETS
# ===============================================================

from pathlib import Path
OUT = Path("../data")
print(OUT)

data = pd.read_csv(OUT / 'Full_dataset_reference.csv', index_col=0, parse_dates=True)
# Out:
# ..\data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4085 entries, 2010-03-15 to 2025-11-26
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S&P500                             4085 non-null   float64
#  1   NASDAQ                             4085 non-null   float64
#  2   DowJones                           4085 non-null   float64
#  3   CAC40                              4085 non-null   float64
#  4   DAX                                4085 non-null   float64
#  5   FTSE100                            4085 non-null   float64
#  6   Nikkei225                          4085 non-null   float64
#  7   HangSeng                           4085 non-null   float64
#  8   MSCIWorld                          4085 non-null   float64
#  9   US10Y                              4085 non-null   float64
#  10  US2Y                               4085 non-null   float64
#  11  TLT                                4085 non-null   float64
#  12  IEF                                4085 non-null   float64
#  13  BND                                4085 non-null   float64
#  14  LQD                                4085 non-null   float64
#  15  Apple                              4085 non-null   float64
#  16  Microsoft                          4085 non-null   float64
#  17  Google                             4085 non-null   float64
#  18  Amazon                             4085 non-null   float64
#  19  Meta                               4085 non-null   float64
#  20  Inflation_CPI                      4085 non-null   float64
#  21  Unemployment_Rate                  4085 non-null   float64
#  22  Fed_Funds_Rate                     4085 non-null   float64
#  23  Real_GDP                           4085 non-null   float64
#  24  Yield_Curve_Spread                 4085 non-null   float64
#  25  Industrial_Production              4085 non-null   float64
#  26  M2_Money_Supply                    4085 non-null   float64
#  27  Personal_Consumption_Expenditures  4085 non-null   float64
#  28  Recession_Probability              4085 non-null   float64
#  29  GDP_Current_USD                    4085 non-null   float64
#  30  Inflation_Annual_Pct               4085 non-null   float64
#  31  Unemployment_Total_Pct             4085 non-null   float64
#  32  Exports_GDP_Pct                    4085 non-null   float64
#  33  Imports_GDP_Pct                    4085 non-null   float64
#  34  Public_Debt_GDP_Pct                4085 non-null   float64
#  35  OECD_CPI_2015idx_USA               4085 non-null   float64
#  36  OECD_Unemp_rate_pct_USA            4085 non-null   float64
#  37  Return                             4085 non-null   float64
#  38  Volatility_20d                     4085 non-null   float64
#  39  MA20                               4085 non-null   float64
#  40  MA50                               4085 non-null   float64
#  41  Momentum                           4085 non-null   float64
#  42  RSI                                4085 non-null   float64
#  43  Direction                          4085 non-null   int64
# dtypes: float64(43), int64(1)
# memory usage: 1.4 MB

# %%
# ===============================================================
# EXPLORATORY DATA ANALYSIS (EDA) – BINARY CLASSIFICATION
# ===============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# ---------------------------------------------------------------
# 1) BASIC INSPECTION
# ---------------------------------------------------------------
print("Shape of dataset:", data.shape)
print("\n--- Data types ---")
print(data.dtypes)

print("\n--- Missing values ---")
print(data.isnull().sum())

print("\n--- First 5 rows ---")
display(data.head())
# Out:
# Shape of dataset: (4085, 44)
#
# --- Data types ---
# S&P500                               float64
# NASDAQ                               float64
# DowJones                             float64
# CAC40                                float64
# DAX                                  float64
# FTSE100                              float64
# Nikkei225                            float64
# HangSeng                             float64
# MSCIWorld                            float64
# US10Y                                float64
# US2Y                                 float64
# TLT                                  float64
# IEF                                  float64
# BND                                  float64
# LQD                                  float64
# Apple                                float64
# Microsoft                            float64
# Google                               float64
# Amazon                               float64
# Meta                                 float64
# Inflation_CPI                        float64
# Unemployment_Rate                    float64
# Fed_Funds_Rate                       float64
# Real_GDP                             float64
# Yield_Curve_Spread                   float64
# Industrial_Production                float64
# M2_Money_Supply                      float64
# Personal_Consumption_Expenditures    float64
# Recession_Probability                float64
# GDP_Current_USD                      float64
# Inflation_Annual_Pct                 float64
# Unemployment_Total_Pct               float64
# Exports_GDP_Pct                      float64
# Imports_GDP_Pct                      float64
# Public_Debt_GDP_Pct                  float64
# OECD_CPI_2015idx_USA                 float64
# OECD_Unemp_rate_pct_USA              float64
# Return                               float64
# Volatility_20d                       float64
# MA20                                 float64
# MA50                                 float64
# Momentum                             float64
# RSI                                  float64
# Direction                              int64
# dtype: object
#
# --- Missing values ---
# S&P500                               0
# NASDAQ                               0
# DowJones                             0
# CAC40                                0
# DAX                                  0
# FTSE100                              0
# Nikkei225                            0
# HangSeng                             0
# MSCIWorld                            0
# US10Y                                0
# US2Y                                 0
# TLT                                  0
# IEF                                  0
# BND                                  0
# LQD                                  0
# Apple                                0
# Microsoft                            0
# Google                               0
# Amazon                               0
# Meta                                 0
# Inflation_CPI                        0
# Unemployment_Rate                    0
# Fed_Funds_Rate                       0
# Real_GDP                             0
# Yield_Curve_Spread                   0
# Industrial_Production                0
# M2_Money_Supply                      0
# Personal_Consumption_Expenditures    0
# Recession_Probability                0
# GDP_Current_USD                      0
# Inflation_Annual_Pct                 0
# Unemployment_Total_Pct               0
# Exports_GDP_Pct                      0
# Imports_GDP_Pct                      0
# Public_Debt_GDP_Pct                  0
# OECD_CPI_2015idx_USA                 0
# OECD_Unemp_rate_pct_USA              0
# Return                               0
# Volatility_20d                       0
# MA20                                 0
# MA50                                 0
# Momentum                             0
# RSI                                  0
# Direction                            0
# dtype: int64
#
# --- First 5 rows ---
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2010-03-15  0.000452 -0.002302  0.001643 -0.009291 -0.006989 -0.005653
# 2010-03-16  0.007779  0.006689  0.004119  0.012347  0.011422  0.004737
# 2010-03-17  0.005822  0.004659  0.004463  0.004808  0.008925  0.004306
# 2010-03-18 -0.000326  0.000917  0.004239 -0.004980 -0.001987 -0.000354
# 2010-03-19 -0.005086 -0.007055 -0.003450 -0.003235 -0.004970  0.001329
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2010-03-15   0.000067 -0.006159        0.0 -0.001617  ...
# 2010-03-16  -0.002815 -0.002665        0.0 -0.013769  ...
# 2010-03-17   0.011684  0.017198        0.0 -0.003011  ...
# 2010-03-18  -0.009491 -0.002517        0.0  0.008237  ...
# 2010-03-19   0.007510  0.001882        0.0  0.004085  ...
#
#             Public_Debt_GDP_Pct  OECD_CPI_2015idx_USA  \
# Date
# 2010-03-15            84.964374              91.67907
# 2010-03-16            84.964374              91.67907
# 2010-03-17            84.964374              91.67907
# 2010-03-18            84.964374              91.67907
# 2010-03-19            84.964374              91.67907
#
#             OECD_Unemp_rate_pct_USA    Return  Volatility_20d      MA20  \
# Date
# 2010-03-15                      9.8 -0.012180        0.012682  0.004875
# 2010-03-16                      9.8  0.002725        0.012642  0.005011
# 2010-03-17                      9.8 -0.001470        0.012552  0.005147
# 2010-03-18                      9.8  0.002365        0.012546  0.005171
# 2010-03-19                      9.8 -0.010683        0.012797  0.004947
#
#                 MA50   Momentum        RSI  Direction
# Date
# 2010-03-15  0.001064 -21.520603  51.075893          1
# 2010-03-16  0.001084  -0.848478  45.971686          0
# 2010-03-17  0.001373  -1.180130  47.804288          1
# 2010-03-18  0.001457  -0.194448  47.103483          0
# 2010-03-19  0.001110  -3.189992  41.466807          1
#
# [5 rows x 44 columns]

# %%
# ---------------------------------------------------------------
# 2) DESCRIPTIVE STATISTICS
# ---------------------------------------------------------------
print("\n--- Descriptive statistics (numeric features) ---")
display(data.describe().T)

# Target variable balance
print("\n--- Target variable distribution ---")
print(data["Direction"].value_counts(normalize=True))
sns.countplot(x="Direction", data=data, palette="Set2")
plt.title("Target Variable Distribution (0=Down, 1=Up)")
plt.show()
# Out:
# --- Descriptive statistics (numeric features) ---
#                                     count          mean           std  \
# S&P500                             4085.0  4.938149e-04  1.077542e-02
# NASDAQ                             4085.0  6.406969e-04  1.276889e-02
# DowJones                           4085.0  4.198063e-04  1.032773e-02
# CAC40                              4085.0  2.497928e-04  1.219803e-02
# DAX                                4085.0  4.070929e-04  1.211078e-02
# FTSE100                            4085.0  1.797741e-04  9.638513e-03
# Nikkei225                          4085.0  4.588959e-04  1.299962e-02
# HangSeng                           4085.0  1.316581e-04  1.283021e-02
# MSCIWorld                          4085.0  4.319742e-04  9.963982e-03
# US10Y                              4085.0  3.947015e-04  2.768881e-02
# US2Y                               4085.0  3.639680e-02  4.383667e-01
# TLT                                4085.0  1.534108e-04  9.395536e-03
# IEF                                4085.0  1.118292e-04  4.126348e-03
# BND                                4085.0  1.017775e-04  3.006045e-03
# LQD                                4085.0  1.635428e-04  4.772105e-03
# Apple                              4085.0  1.061335e-03  1.748908e-02
# Microsoft                          4085.0  8.835960e-04  1.585733e-02
# Google                             4085.0  9.065910e-04  1.719663e-02
# Amazon                             4085.0  1.076620e-03  2.040789e-02
# Meta                               4085.0  9.505964e-04  2.288567e-02
# Inflation_CPI                      4085.0  2.585014e+02  3.158532e+01
# Unemployment_Rate                  4085.0  5.658800e+00  2.163350e+00
# Fed_Funds_Rate                     4085.0  1.420343e+00  1.815296e+00
# Real_GDP                           4085.0  1.998993e+04  2.152748e+03
# OECD_CPI_2015idx_USA               1.176464e+02  1.364395e+02
# OECD_Unemp_rate_pct_USA            7.300000e+00  1.480000e+01
# Return                             9.822724e-03  1.532884e-01
# Volatility_20d                     1.873205e-02  6.800405e-02
# MA20                               3.618556e-03  1.532091e-02
# MA50                               2.622802e-03  8.216519e-03
# Momentum                           2.390495e-02           inf
# RSI                                5.299847e+01  7.557520e+01
# Direction                          1.000000e+00  1.000000e+00
# --- Target variable distribution ---
# Direction
# 1    0.512607
# 0    0.487393
# Name: proportion, dtype: float64

# %%
# ---------------------------------------------------------------
# 3) CORRELATION ANALYSIS
# ---------------------------------------------------------------
numeric_features = data.drop(columns=["Direction"]).select_dtypes(include=[np.number])
corr = numeric_features.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap – Numeric Features")
plt.show()

# Correlation with target
corr_target = data.corr()["Direction"].sort_values(ascending=False)
print("\n--- Correlation of each feature with Direction ---")
display(corr_target)
# Out:
# --- Correlation of each feature with Direction ---
# Direction                            1.000000
# LQD                                  0.040865
# HangSeng                             0.038330
# Nikkei225                            0.026822
# BND                                  0.025731
# IEF                                  0.025437
# MA20                                 0.023662
# TLT                                  0.022559
# US2Y                                 0.018248
# Fed_Funds_Rate                       0.013746
# OECD_Unemp_rate_pct_USA              0.012367
# Unemployment_Rate                    0.011767
# Personal_Consumption_Expenditures    0.008360
# GDP_Current_USD                      0.008028
# Real_GDP                             0.007753
# Inflation_CPI                        0.007036
# OECD_CPI_2015idx_USA                 0.006923
# M2_Money_Supply                      0.005437
# Public_Debt_GDP_Pct                  0.003795
# MA50                                 0.003235
# RSI                                  0.000764
# FTSE100                             -0.000632
# Unemployment_Total_Pct              -0.002437
# NASDAQ                              -0.002642
# Amazon                              -0.003893
# Google                              -0.004951
# Meta                                -0.005240
# CAC40                               -0.005630
# Microsoft                           -0.006934
# Apple                               -0.008442
# Return                              -0.008442
# S&P500                              -0.008845
# Industrial_Production               -0.009339
# DAX                                 -0.009983
# Yield_Curve_Spread                  -0.012090
# Volatility_20d                      -0.012893
# Momentum                            -0.015128
# Inflation_Annual_Pct                -0.015191
# Recession_Probability               -0.016737
# Exports_GDP_Pct                     -0.016960
# Imports_GDP_Pct                     -0.020357
# DowJones                            -0.021823
# MSCIWorld                           -0.023773
# US10Y                               -0.044225
# Name: Direction, dtype: float64

# %%
# ---------------------------------------------------------------
# 4) OUTLIER DETECTION
# ---------------------------------------------------------------
# Using z-score method
z_scores = np.abs(stats.zscore(numeric_features))
outlier_rows = np.where(z_scores > 3)
print(f"\nNumber of outliers (|z|>3): {len(outlier_rows[0])}")
# Out:
# Number of outliers (|z|>3): 1721

# %%
# ---------------------------------------------------------------
# 5) FEATURE DISTRIBUTIONS
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# CLEAN NUMERIC FEATURES BEFORE PLOTTING
# ---------------------------------------------------------------
numeric_features_clean = numeric_features.replace([np.inf, -np.inf], np.nan).dropna(axis=1, how='all')

# Plot histograms only for columns with finite values
numeric_features_clean.hist(
    bins=40,
    figsize=(14,10),
    layout=(int(np.ceil(len(numeric_features_clean.columns)/4)),4)
)
plt.suptitle("Feature Distributions (Cleaned Numeric Data)")
plt.show()

# %%
# ---------------------------------------------------------------
# 6) CLEANING AND SCALING – ROBUST VERSION
# ---------------------------------------------------------------

# 6A) Replace infinite values and fill missing data
data_clean = data.copy()
numeric_cols = data.drop(columns=["Direction"]).select_dtypes(include=[np.number]).columns

# Replace infinities with NaN
data_clean[numeric_cols] = data_clean[numeric_cols].replace([np.inf, -np.inf], np.nan)

# Fill NaN with median (safer than mean)
data_clean[numeric_cols] = data_clean[numeric_cols].fillna(data_clean[numeric_cols].median())

# Optionally: cap extreme outliers to avoid exploding scales
for col in numeric_cols:
    q_low, q_high = data_clean[col].quantile([0.01, 0.99])
    data_clean[col] = data_clean[col].clip(lower=q_low, upper=q_high)

# 6B) Standardize numeric features safely
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

data_scaled = data_clean.copy()
data_scaled[numeric_cols] = scaler.fit_transform(data_clean[numeric_cols])

print("\n OK Data cleaned and scaled successfully.")
display(data_scaled.head())
# Out:
#  OK Data cleaned and scaled successfully.
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2010-03-15 -0.002354 -0.249295  0.138139 -0.853390 -0.663445 -0.662621
# 2010-03-16  0.772371  0.520087  0.417374  1.083811  0.986356  0.511981
# 2010-03-17  0.565397  0.346427  0.456212  0.408914  0.762580  0.463197
# 2010-03-18 -0.084621  0.026133  0.430964 -0.467414 -0.215216 -0.063634
# 2010-03-19 -0.587992 -0.656045 -0.436471 -0.311194 -0.482511  0.126688
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2010-03-15  -0.033282 -0.533628  -0.049806 -0.084014  ...
# 2010-03-16  -0.278832 -0.237964  -0.049806 -0.617845  ...
# 2010-03-17   0.956352  1.442506  -0.049806 -0.145254  ...
# 2010-03-18  -0.847543 -0.225449  -0.049806  0.348903  ...
# 2010-03-19   0.600798  0.146724  -0.049806  0.166492  ...
#
#             Public_Debt_GDP_Pct  OECD_CPI_2015idx_USA  \
# Date
# 2010-03-15            -1.619851             -1.297184
# 2010-03-16            -1.619851             -1.297184
# 2010-03-17            -1.619851             -1.297184
# 2010-03-18            -1.619851             -1.297184
# 2010-03-19            -1.619851             -1.297184
#
#             OECD_Unemp_rate_pct_USA    Return  Volatility_20d      MA20  \
# Date
# 2010-03-15                 1.918955 -0.829170       -0.490003  1.062391
# 2010-03-16                 1.918955  0.106311       -0.496255  1.100507
# 2010-03-17                 1.918955 -0.156974       -0.510047  1.138399
# 2010-03-18                 1.918955  0.083697       -0.511006  1.145228
# 2010-03-19                 1.918955 -0.735215       -0.472313  1.082649
#
#                 MA50  Momentum       RSI  Direction
# Date
# 2010-03-15 -0.005455 -3.460609  0.255147          1
# 2010-03-16  0.003306  0.021673 -0.804701          0
# 2010-03-17  0.130315 -0.034194 -0.424176          1
# 2010-03-18  0.167383  0.131847 -0.569692          0
# 2010-03-19  0.014902 -0.372762 -1.740103          1
#
# [5 rows x 44 columns]

# %%
# ---------------------------------------------------------------
# 7) SENSITIVITY ANALYSIS (Feature vs Target)
# ---------------------------------------------------------------
# Point-biserial correlation (numerical vs binary target)
from scipy.stats import pointbiserialr

sensitivity = {}
for col in numeric_features.columns:
    corr_val, p_val = pointbiserialr(data_scaled[col], data_scaled["Direction"])
    sensitivity[col] = [corr_val, p_val]

sensitivity_df = pd.DataFrame(sensitivity, index=["Correlation", "p-value"]).T
sensitivity_df.sort_values("Correlation", ascending=False, inplace=True)

print("\n--- Sensitivity (Point-biserial correlation with target) ---")
display(sensitivity_df)

plt.figure(figsize=(10,5))
sns.barplot(x=sensitivity_df.index, y=sensitivity_df["Correlation"], palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Feature Sensitivity to Target (Correlation Strength)")
plt.show()
# Out:
# --- Sensitivity (Point-biserial correlation with target) ---
#                                    Correlation   p-value
# HangSeng                              0.037676  0.016034
# LQD                                   0.036545  0.019502
# BND                                   0.029331  0.060867
# MA20                                  0.024644  0.115293
# IEF                                   0.024401  0.118923
# TLT                                   0.020659  0.186797
# Nikkei225                             0.018773  0.230300
# Fed_Funds_Rate                        0.013746  0.379779
# OECD_Unemp_rate_pct_USA               0.011904  0.446888
# Unemployment_Rate                     0.011637  0.457128
# Personal_Consumption_Expenditures     0.008388  0.591984
# GDP_Current_USD                       0.008028  0.607969
# Real_GDP                              0.007841  0.616381
# Inflation_CPI                         0.007035  0.653086
# OECD_CPI_2015idx_USA                  0.006921  0.658350
# NASDAQ                                0.006475  0.679099
# US2Y                                  0.006340  0.685404
# M2_Money_Supply                       0.005469  0.726764
# Momentum                              0.005024  0.748185
# FTSE100                               0.004336  0.781724
# MA50                                  0.004136  0.791572
# Public_Debt_GDP_Pct                   0.003795  0.808423
# S&P500                                0.002569  0.869608
# RSI                                   0.000887  0.954811
# Microsoft                             0.000838  0.957291
# Amazon                               -0.001343  0.931599
# CAC40                                -0.001981  0.899294
# Unemployment_Total_Pct               -0.002437  0.876247
# DAX                                  -0.004970  0.750798
# Return                               -0.005284  0.735632
# Apple                                -0.005284  0.735632
# Industrial_Production                -0.009272  0.553554
# DowJones                             -0.009812  0.530678
# Google                               -0.011535  0.461093
# MSCIWorld                            -0.011543  0.460789
# Meta                                 -0.011648  0.456711
# Yield_Curve_Spread                   -0.012511  0.424035
# Volatility_20d                       -0.013880  0.375120
# Inflation_Annual_Pct                 -0.015191  0.331712
# Recession_Probability                -0.016734  0.284943
# Exports_GDP_Pct                      -0.016960  0.278488
# Imports_GDP_Pct                      -0.020357  0.193312
# US10Y                                -0.032713  0.036552

# %%
# ---------------------------------------------------------------
# 8) OPTIONAL: PAIRPLOT FOR VISUAL EXPLORATION
# ---------------------------------------------------------------
sample_cols = ["Direction"] + list(sensitivity_df.index[:4])  # top 4 features
sns.pairplot(data_scaled[sample_cols], hue="Direction", diag_kind="kde", palette="husl")
plt.suptitle("Pairwise Feature Relationships vs Target", y=1.02)
plt.show()

# %%
data.to_csv(OUT / "Cleaned_Features_for_ML.csv")
