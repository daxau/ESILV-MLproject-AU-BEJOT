# %% [raw]
# # ===============================================================
# # MACHINE LEARNING PROJECT - 2025 GUIDELINES COMPLIANT
# # Title: Stock Price Direction Forecasting using Macroeconomic Indicators
# # Author: Dax AU / Téofil BEJOT
# # ===============================================================
#
# # Stock Price Direction Forecasting using Macroeconomic Indicators
# # -To predict whether a stock’s next-day return will be positive or negative, based on historical returns and macro-economic variables.
#
# # Predicting Apple Stock Direction — Full ML Pipeline
# # This notebook covers this single step:
# 3) Data exploration & preprocessing to generate the clean dataset for model training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, confusion_matrix, classification_report, RocCurveDisplay
import shap
import warnings

warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %%
# ===============================================================
# 1) LOAD DATASETS
# ===============================================================

from pathlib import Path
OUT = Path("../data")
print(OUT)

data = pd.read_csv(OUT / 'Full_dataset_reference.csv', index_col=0, parse_dates=True)
# Out:
# ..\data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4091 entries, 2010-03-15 to 2025-12-04
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S&P500                             4091 non-null   float64
#  1   NASDAQ                             4091 non-null   float64
#  2   DowJones                           4091 non-null   float64
#  3   CAC40                              4091 non-null   float64
#  4   DAX                                4091 non-null   float64
#  5   FTSE100                            4091 non-null   float64
#  6   Nikkei225                          4091 non-null   float64
#  7   HangSeng                           4091 non-null   float64
#  8   MSCIWorld                          4091 non-null   float64
#  9   US10Y                              4091 non-null   float64
#  10  US2Y                               4091 non-null   float64
# ...

# %%
print(data.tail(10))
# Out:
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2025-11-21  0.009823  0.008834  0.010779  0.000198 -0.008032  0.001259
# 2025-11-24  0.015467  0.026890  0.004387 -0.002879  0.006379 -0.000503
# 2025-11-25  0.009062  0.006715  0.014299  0.008308  0.009701  0.007824
# 2025-11-26  0.006907  0.008213  0.006679  0.008800  0.011148  0.008544
# 2025-11-27  0.005355  0.006505  0.006100  0.000375  0.001759  0.000237
# 2025-11-28  0.000000  0.000000  0.000000  0.002869  0.002896  0.002744
# 2025-12-01 -0.005323 -0.003842 -0.008951 -0.003165 -0.010377 -0.001852
# 2025-12-02  0.002457  0.005918  0.003915 -0.002765  0.005147 -0.000072
# 2025-12-03  0.002980  0.001726  0.008603  0.001586 -0.000723 -0.001000
# 2025-12-04  0.001080  0.002177 -0.000667  0.004279  0.007948  0.001940
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2025-11-21  -0.024046 -0.023826   0.010603 -0.010472  ...
# ...

# %%
# ===============================================================
# EXPLORATORY DATA ANALYSIS (EDA) – BINARY CLASSIFICATION
# ===============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# ---------------------------------------------------------------
# 1) BASIC INSPECTION
# ---------------------------------------------------------------
print("Shape of dataset:", data.shape)
print("\n--- Data types ---")
print(data.dtypes)

print("\n--- Missing values ---")
print(data.isnull().sum())

print("\n--- First 5 rows ---")
display(data.head())
# Out:
# Shape of dataset: (4091, 44)
#
# --- Data types ---
# S&P500                               float64
# NASDAQ                               float64
# DowJones                             float64
# CAC40                                float64
# DAX                                  float64
# FTSE100                              float64
# Nikkei225                            float64
# HangSeng                             float64
# MSCIWorld                            float64
# US10Y                                float64
# US2Y                                 float64
# TLT                                  float64
# IEF                                  float64
# BND                                  float64
# LQD                                  float64
# Apple                                float64
# Microsoft                            float64
# Google                               float64
# Amazon                               float64
# Meta                                 float64
# ...

# %% [raw]
# This section performs an initial exploratory analysis of the engineered dataset used for binary classification.
# It reports the overall shape of the DataFrame (4,085 rows and 44 columns), followed by the data types of each variable, confirming that all features are numerical except for the binary target Direction.
#
# The missing value check shows that the dataset is fully complete after preprocessing, with no NaN entries remaining.
# Finally, the first five rows are displayed to provide a quick visual inspection of the combined features, including market indices, macroeconomic indicators, technical signals, and the target variable.

# %%
# ---------------------------------------------------------------
# 2) DESCRIPTIVE STATISTICS
# ---------------------------------------------------------------
print("\n--- Descriptive statistics (numeric features) ---")
display(data.describe().T)

# Target variable balance
print("\n--- Target variable distribution ---")
print(data["Direction"].value_counts(normalize=True))
sns.countplot(x="Direction", data=data, palette="Set2")
plt.title("Target Variable Distribution (0=Down, 1=Up)")
plt.show()
# Out:
# --- Descriptive statistics (numeric features) ---
#                                     count          mean           std  \
# S&P500                             4091.0  4.946914e-04  1.076829e-02
# NASDAQ                             4091.0  6.428088e-04  1.276034e-02
# DowJones                           4091.0  4.213905e-04  1.032253e-02
# CAC40                              4091.0  2.502039e-04  1.218954e-02
# DAX                                4091.0  4.081215e-04  1.210396e-02
# FTSE100                            4091.0  1.799992e-04  9.631635e-03
# Nikkei225                          4091.0  4.655089e-04  1.300098e-02
# HangSeng                           4091.0  1.315723e-04  1.282340e-02
# MSCIWorld                          4091.0  4.333521e-04  9.957445e-03
# US10Y                              4091.0  4.008327e-04  2.767116e-02
# US2Y                               4091.0  3.633411e-02  4.380481e-01
# TLT                                4091.0  1.484639e-04  9.391506e-03
# ...

# %% [raw]
# This section provides a descriptive summary of all numerical features in the dataset.
# The statistics include the mean, standard deviation, quartiles, and the full range for each variable, allowing quick identification of scale differences, volatility levels, and potential outliers across market indices, macroeconomic variables, and technical indicators.
#
# The target variable Direction is also examined.
# Its distribution is almost perfectly balanced, with approximately 51% upward movements (class 1) and 49% downward movements (class 0).
# The accompanying count plot visually confirms this balance, indicating that the binary classification problem does not suffer from class imbalance and is suitable for standard machine learning algorithms without requiring resampling techniques.

# %%
# ---------------------------------------------------------------
# 3) CORRELATION ANALYSIS
# ---------------------------------------------------------------
numeric_features = data.drop(columns=["Direction"]).select_dtypes(include=[np.number])
corr = numeric_features.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap – Numeric Features")
plt.show()

# Correlation with target
corr_target = data.corr()["Direction"].sort_values(ascending=False)
print("\n--- Correlation of each feature with Direction ---")
display(corr_target)
# Out:
# --- Correlation of each feature with Direction ---
# Direction                            1.000000
# LQD                                  0.040937
# HangSeng                             0.038464
# Nikkei225                            0.026255
# BND                                  0.025654
# IEF                                  0.025314
# MA20                                 0.023508
# TLT                                  0.022634
# US2Y                                 0.018265
# Fed_Funds_Rate                       0.013655
# OECD_Unemp_rate_pct_USA              0.012378
# Unemployment_Rate                    0.011777
# Personal_Consumption_Expenditures    0.008273
# GDP_Current_USD                      0.007939
# Real_GDP                             0.007665
# Inflation_CPI                        0.006932
# OECD_CPI_2015idx_USA                 0.006819
# M2_Money_Supply                      0.005367
# Public_Debt_GDP_Pct                  0.003751
# ...

# %% [raw]
# The correlation heatmap provides an overview of linear relationships among all numerical features.
# Strong positive correlations are visible within groups of related variables, such as global equity indices, bond ETFs, and macroeconomic indicators, while cross-class correlations remain weaker.
# This structure suggests that the dataset contains well-defined feature clusters rather than redundant duplicates.
#
# The feature-to-target correlation analysis shows that no single variable exhibits strong predictive power for the binary direction of returns.
# All correlations with Direction are close to zero, which is typical for daily financial data where movements are highly noisy and weakly autocorrelated.
# A few market variables (such as LQD, HangSeng, and Nikkei225) show slightly positive correlations, while others (such as US10Y, MSCIWorld, and DowJones) show small negative correlations.
#
# Overall, the results indicate that classification models will need to rely on multivariate patterns rather than single-feature signals, reinforcing the necessity of machine-learning approaches rather than simple threshold rules.

# %%
# ---------------------------------------------------------------
# 4) OUTLIER DETECTION
# ---------------------------------------------------------------
# Using z-score method
z_scores = np.abs(stats.zscore(numeric_features))
outlier_rows = np.where(z_scores > 3)
print(f"\nNumber of outliers (|z|>3): {len(outlier_rows[0])}")
# Out:
# Number of outliers (|z|>3): 1725

# %% [raw]
# This step applies a z-score–based method to identify extreme values across all numerical features.
# Values with an absolute z-score greater than 3 are flagged as statistical outliers, which is a common threshold in normally distributed data.
#
# The result shows that 1,721 observations exceed this cutoff, indicating the presence of substantial tail events.
# This is expected in financial time series, where volatility spikes, macroeconomic shocks, and market stress periods naturally produce heavy-tailed distributions.
# Outliers may therefore provide meaningful information rather than noise, and should be handled cautiously depending on the modeling strategy.

# %%
# ---------------------------------------------------------------
# 5) FEATURE DISTRIBUTIONS
# ---------------------------------------------------------------
# ---------------------------------------------------------------
# CLEAN NUMERIC FEATURES BEFORE PLOTTING
# ---------------------------------------------------------------
numeric_features_clean = numeric_features.replace([np.inf, -np.inf], np.nan).dropna(axis=1, how='all')

# Plot histograms only for columns with finite values
numeric_features_clean.hist(
    bins=40,
    figsize=(14,10),
    layout=(int(np.ceil(len(numeric_features_clean.columns)/4)),4)
)
plt.suptitle("Feature Distributions (Cleaned Numeric Data)")
plt.show()

# %% [raw]
# This section visualizes the distribution of all cleaned numerical features after removing invalid or infinite values.
# Most financial return series (equity indices, stocks, bond ETFs) exhibit bell-shaped distributions centered near zero, which is consistent with daily log-return behavior and market efficiency.
#
# Macroeconomic variables show more structured patterns: some are right-skewed (such as inflation measures), others display wide ranges or discrete jumps due to reporting frequency and economic cycles.
# Technical indicators such as momentum, RSI, and moving averages also present characteristic shapes tied to their calculation windows.
#
# These histograms highlight the heterogeneous nature of the dataset, confirming that different groups of features follow very different statistical distributions.
# Such diversity reinforces the need for scaling, normalization, or model architectures capable of handling features on different scales.

# %%
# ---------------------------------------------------------------
# 6) CLEANING AND SCALING – ROBUST VERSION
# ---------------------------------------------------------------

# Replace infinite values and fill missing data
data_clean = data.copy()
numeric_cols = data.drop(columns=["Direction"]).select_dtypes(include=[np.number]).columns

# Replace infinities with NaN
data_clean[numeric_cols] = data_clean[numeric_cols].replace([np.inf, -np.inf], np.nan)

# Fill NaN with median (safer than mean)
data_clean[numeric_cols] = data_clean[numeric_cols].fillna(data_clean[numeric_cols].median())

# Cap extreme outliers to avoid exploding scales
for col in numeric_cols:
    q_low, q_high = data_clean[col].quantile([0.01, 0.99])
    data_clean[col] = data_clean[col].clip(lower=q_low, upper=q_high)

# Standardize numeric features safely
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

data_scaled = data_clean.copy()
data_scaled[numeric_cols] = scaler.fit_transform(data_clean[numeric_cols])

print("\n OK Data cleaned and scaled successfully.")
display(data_scaled.head())
# Out:
#  OK Data cleaned and scaled successfully.
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2010-03-15 -0.002498 -0.249648  0.138054 -0.854086 -0.663930 -0.663189
# 2010-03-16  0.772874  0.520252  0.417438  1.084684  0.986877  0.512362
# 2010-03-17  0.565728  0.346475  0.456297  0.409241  0.762965  0.463538
# 2010-03-18 -0.084834  0.025965  0.431035 -0.467797 -0.215427 -0.063718
# 2010-03-19 -0.588626 -0.656672 -0.436863 -0.311451 -0.482886  0.126757
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2010-03-15  -0.033835 -0.533965  -0.050012 -0.084336  ...
# 2010-03-16  -0.279318 -0.238109  -0.050012 -0.618524  ...
# 2010-03-17   0.955530  1.443451  -0.050012 -0.145617  ...
# 2010-03-18  -0.847875 -0.225585  -0.050012  0.348869  ...
# 2010-03-19   0.600073  0.146829  -0.050012  0.166336  ...
#
#             Public_Debt_GDP_Pct  OECD_CPI_2015idx_USA  \
# Date
# ...

# %% [raw]
# This section applies a robust preprocessing pipeline to ensure the numerical features are clean, consistent, and properly scaled for machine-learning models.
#
# First, infinite values are replaced with NaN, and all missing entries are imputed using the median of each feature, which is more robust to extreme values than the mean.
# A 1st–99th percentile clipping is then applied to limit the influence of extreme outliers while preserving the overall structure of the data.
#
# Finally, all numeric columns are standardized using StandardScaler, transforming each variable to zero mean and unit variance.
# This step is essential because the dataset contains features with very different scales, and normalization helps improve model convergence and stability.
#
# The first rows of data_scaled confirm that the cleaned and rescaled features are now centered and comparable across variables, while the target column Direction remains unchanged.

# %%
# ---------------------------------------------------------------
# 7) SENSITIVITY ANALYSIS (Feature vs Target)
# ---------------------------------------------------------------
# Point-biserial correlation (numerical vs binary target)
from scipy.stats import pointbiserialr

sensitivity = {}
for col in numeric_features.columns:
    corr_val, p_val = pointbiserialr(data_scaled[col], data_scaled["Direction"])
    sensitivity[col] = [corr_val, p_val]

sensitivity_df = pd.DataFrame(sensitivity, index=["Correlation", "p-value"]).T
sensitivity_df.sort_values("Correlation", ascending=False, inplace=True)

print("\n--- Sensitivity (Point-biserial correlation with target) ---")
display(sensitivity_df)

plt.figure(figsize=(10,5))
sns.barplot(x=sensitivity_df.index, y=sensitivity_df["Correlation"], palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Feature Sensitivity to Target (Correlation Strength)")
plt.show()
# Out:
# --- Sensitivity (Point-biserial correlation with target) ---
#                                    Correlation   p-value
# HangSeng                              0.037825  0.015545
# LQD                                   0.036642  0.019093
# BND                                   0.029237  0.061508
# MA20                                  0.024487  0.117362
# IEF                                   0.024272  0.120607
# TLT                                   0.020738  0.184791
# Nikkei225                             0.018158  0.245577
# Fed_Funds_Rate                        0.013655  0.382590
# OECD_Unemp_rate_pct_USA               0.011915  0.446120
# Unemployment_Rate                     0.011648  0.456402
# Personal_Consumption_Expenditures     0.008301  0.595574
# GDP_Current_USD                       0.007939  0.611705
# Real_GDP                              0.007752  0.620098
# Inflation_CPI                         0.006930  0.657666
# ...

# %% [raw]
# This section evaluates the sensitivity of each numerical feature to the binary target using point-biserial correlation, which is the appropriate statistical measure for assessing relationships between continuous variables and a binary outcome.
#
# The results confirm that no single feature shows strong explanatory power for predicting daily directional movements.
# Most correlations are very close to zero, which is typical for short-term financial forecasting due to high noise levels and limited linear relationships.
#
# A few features—such as Hang Seng, LQD, and BND—exhibit slightly positive correlations, while others like US10Y and several macroeconomic variables show small negative correlations.
# These weak magnitudes indicate that the predictive signal is likely distributed across many features rather than being concentrated in any specific indicator.
#
# The barplot visualizes the ordered correlation strengths, reinforcing the conclusion that successful modeling will depend on multivariate interactions captured through machine-learning algorithms, rather than relying on any single dominant feature.

# %%
# ---------------------------------------------------------------
# 8) PAIRPLOT FOR VISUAL EXPLORATION
# ---------------------------------------------------------------
sample_cols = ["Direction"] + list(sensitivity_df.index[:4])  # top 4 features
sns.pairplot(data_scaled[sample_cols], hue="Direction", diag_kind="kde", palette="husl")
plt.suptitle("Pairwise Feature Relationships vs Target", y=1.02)
plt.show()

# %% [raw]
# This pairplot visualizes the relationships between the most sensitive features (based on point-biserial correlation) and the binary target Direction.
# The diagonal density plots show that both classes (0 = down, 1 = up) have almost identical univariate distributions for each feature, indicating a lack of strong single-variable separation.
#
# The scatterplots in the off-diagonal panels also reveal substantial overlap between the two classes, with no clear clustering or linear boundaries.
# This confirms that daily directional movements are not easily explained by simple bivariate relationships.
#
# Overall, the visualization reinforces earlier conclusions:
# the predictive signal, if present, is highly diffuse and likely emerges only from complex multivariate interactions rather than from individual features or pairwise relationships.
# Machine-learning models capable of capturing nonlinear combinations of features (e.g., tree-based ensembles or neural networks) are therefore more appropriate than simple threshold-based or linear models.

# %%
data_scaled.to_csv(OUT / "Cleaned_Features_for_ML.csv")
