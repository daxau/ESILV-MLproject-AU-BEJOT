# %% [raw]
# # ===============================================================
# # MACHINE LEARNING PROJECT - 2025 GUIDELINES COMPLIANT
# # Title: Stock Price Direction Forecasting using Macroeconomic Indicators
# # Author: Dax AU / Téofil BEJOT
# # ===============================================================
#
# # Stock Price Direction Forecasting using Macroeconomic Indicators
# # -To predict whether a stock’s next-day return will be positive or negative, based on historical returns and macro-economic variables.
#
# # Datasets
# # -Yahoo Finance or Quandl for daily stock prices (e.g., AAPL, MSFT, CAC40, S&P500).
# # -FRED / World Bank Open Data for interest rates, inflation (CPI), unemployment, GDP growth, etc.
#
# # Techniques
# # -Logistic Regression, Random Forest, XGBoost, LSTM for sequential data --> Metrics: Accuracy, ROC-AUC, Precision/Recall, Confusion Matrix.
#
# # Sources and data
# # -API / Library: yfinance : Clean daily data, Covers global equities (S&P500, CAC40, etc.), Easy to access and integrate
# # -URL: https://www.quandl.com: Reliable & documented, Many macro indicators are mirrored from FRED and OECD
# # -The Federal Reserve Economic Data (FRED) is a standard for macro variables.
# # -Market Data: Daily close, returns, volume, volatility  --> Yahoo Finance, Quandl, Daily yfinance, quandl
# # -Macroeconomic Indicators: CPI, GDP growth, interest rate, unemployment, yield spread --> FRED, World Bank, OECD Monthly / Quarterly fred api
#
# # Predicting Apple Stock Direction — Full ML Pipeline
# # This notebook covers these steps:
# 1) Import libraries & dataset
# 2) Create binary target ("Direction") for Apple stock Price

# %%
# ===============================================================
# ML Project — Macro + Market Data
# Pipeline : FRED + WorldBank + OCDE(KEI/DB.NOMICS) → Merge → Weekly → GB
# Output files : CSV
# ===============================================================

# =========================
# 0) Data Import
# =========================
import re, datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import wbdata
import requests
import yfinance as yf
from pathlib import Path

START_DATE = "2010-01-01"
END_DATE   = "2025-09-01"
date_index = pd.date_range(start=START_DATE, end=END_DATE, freq="D")

# Works in a Jupyter notebook located in /notebooks/
OUT = Path("../data")
OUT.mkdir(parents=True, exist_ok=True)

# %% [raw]
# FRED Data
#
# We retrieve the classic U.S. macroeconomic series (CPI, unemployment, Fed Funds, real GDP, industrial production, money supply, PCE, recession probability). All data are resampled to a daily index and forward-filled. The anti-leakage lag will be applied during the multi-source merge.

# %%
# ==============================
# 1) FRED — Times Series
# ==============================
fred_series = {
    "CPIAUCSL": "Inflation_CPI",
    "UNRATE": "Unemployment_Rate",
    "FEDFUNDS": "Fed_Funds_Rate",
    "GDPC1": "Real_GDP",
    "T10Y3M": "Yield_Curve_Spread",
    "INDPRO": "Industrial_Production",
    "M2SL": "M2_Money_Supply",
    "PCE": "Personal_Consumption_Expenditures",
    "RECPROUSM156N": "Recession_Probability",
}
fred_data = pdr.DataReader(list(fred_series.keys()), "fred", start=START_DATE, end=END_DATE)
fred_data.rename(columns=fred_series, inplace=True)
fred_data = fred_data.sort_index().reindex(date_index).ffill().bfill()

from IPython.display import display
print("FRED shape:", fred_data.shape)
display(fred_data.head())
# Out:
# FRED shape: (5723, 9)
#             Inflation_CPI  Unemployment_Rate  Fed_Funds_Rate  Real_GDP  \
# 2010-01-01        217.488                9.8            0.11  16582.71
# %%
# ==============================
# 2) WORLD BANK — USA
# ==============================
wb_indicators = {
    "NY.GDP.MKTP.CD": "GDP_Current_USD",
    "FP.CPI.TOTL.ZG": "Inflation_Annual_Pct",
    "SL.UEM.TOTL.ZS": "Unemployment_Total_Pct",
    "NE.EXP.GNFS.ZS": "Exports_GDP_Pct",
    "NE.IMP.GNFS.ZS": "Imports_GDP_Pct",
    "GC.DOD.TOTL.GD.ZS": "Public_Debt_GDP_Pct",
}
try:
    wb_data = wbdata.get_dataframe(
        wb_indicators, country="US",
        date=(dt.datetime(2010,1,1), dt.datetime(2025,9,1))
    )
except TypeError:
    wb_data = wbdata.get_dataframe(
        wb_indicators, country="US",
        data_date=(dt.datetime(2010,1,1), dt.datetime(2025,9,1))
    )
wb_data.index = pd.to_datetime(wb_data.index, errors="coerce")
wb_data = wb_data.sort_index().reindex(date_index).ffill().bfill()

print("World Bank shape:", wb_data.shape)
display(wb_data.head())
# Out:
# World Bank shape: (5723, 6)
#             GDP_Current_USD  Inflation_Annual_Pct  Unemployment_Total_Pct  \
# 2010-01-01     1.504897e+13              1.640043                   9.633
# 2010-01-02     1.504897e+13              1.640043                   9.633
# 2010-01-03     1.504897e+13              1.640043                   9.633
# 2010-01-04     1.504897e+13              1.640043                   9.633
# 2010-01-05     1.504897e+13              1.640043                   9.633
#
#             Exports_GDP_Pct  Imports_GDP_Pct  Public_Debt_GDP_Pct
# 2010-01-01        12.341355        15.878528            84.964374
# 2010-01-02        12.341355        15.878528            84.964374
# 2010-01-03        12.341355        15.878528            84.964374
# 2010-01-04        12.341355        15.878528            84.964374
# 2010-01-05        12.341355        15.878528            84.964374

# %%
from IPython.display import display
print("World Bank — 2025:")
display(wb_data.loc["2025"])
# Out:
# World Bank — 2025:
#             GDP_Current_USD  Inflation_Annual_Pct  Unemployment_Total_Pct  \
# 2025-01-01     2.918489e+13              2.949525                   4.106
# 2025-01-02     2.918489e+13              2.949525                   4.106
# 2025-01-03     2.918489e+13              2.949525                   4.106
# 2025-01-04     2.918489e+13              2.949525                   4.106
# 2025-01-05     2.918489e+13              2.949525                   4.106
# ...                     ...                   ...                     ...
# 2025-08-28     2.918489e+13              2.949525                   4.106
# 2025-08-29     2.918489e+13              2.949525                   4.106
# 2025-08-30     2.918489e+13              2.949525                   4.106
# 2025-08-31     2.918489e+13              2.949525                   4.106
# 2025-09-01     2.918489e+13              2.949525                   4.106
#
#             Exports_GDP_Pct  Imports_GDP_Pct  Public_Debt_GDP_Pct
# 2025-01-01        10.896875        13.991117           114.755553
# 2025-01-02        10.896875        13.991117           114.755553
# 2025-01-03        10.896875        13.991117           114.755553
# 2025-01-04        10.896875        13.991117           114.755553
# 2025-01-05        10.896875        13.991117           114.755553
# ...                     ...              ...                  ...
# 2025-08-28        10.896875        13.991117           114.755553
# 2025-08-29        10.896875        13.991117           114.755553
# 2025-08-30        10.896875        13.991117           114.755553
# 2025-08-31        10.896875        13.991117           114.755553
# 2025-09-01        10.896875        13.991117           114.755553
#
# [244 rows x 6 columns]

# %% [raw]
# OECD/KEI via DB.NOMICS + Fallback Mechanism
#
# We download CPI (base 2015 = 100, monthly) and unemployment (%). Since some CSV files may be incomplete, a clean fallback is provided from FRED: – CPI2015idx reconstructed from CPIAUCSL; – Unemployment rate from UNRATE. Goal: an OECD block with no missing values.

# %%
# =================================================
# 3) OCDE (KEI) via DB.NOMICS — CPI & Unemployment
# =================================================
def oecd_kei_to_wide(series_ids):
    base = "https://api.db.nomics.world/v22/series?observations=1&format=csv&series_ids="
    url = base + ",".join(series_ids)
    df = pd.read_csv(url, low_memory=False)

    # trouver colonne période
    pcol = next((c for c in df.columns if c.strip().lower() in {"period","time","time_period","date"}), None)
    if pcol is None:
        raise KeyError(f"Colonne période introuvable: {list(df.columns)[:10]}")
    df = df.rename(columns={pcol: "period"})

    # renommer colonnes → extraire ID entre parenthèses (...(OECD/KEI/...))
    ren = {}
    for c in df.columns:
        if c == "period": continue
        m = re.search(r"\(([^()]+)\)\s*$", str(c))
        ren[c] = (m.group(1) if m else c).upper()
    df = df.rename(columns=ren)

    keep = ["period"] + [s.upper() for s in series_ids]
    missing = [s for s in series_ids if s.upper() not in df.columns]
    if missing:
        # On laisse passer, on créera un fallback
        print("⚠️ Séries OCDE manquantes dans le CSV:", missing)
        keep = [k for k in keep if k in df.columns]
    wide = df[keep].copy()

    # index = fin de mois
    wide.index = pd.PeriodIndex(wide["period"].astype(str), freq="M").end_time
    wide = wide.drop(columns=["period"]).sort_index()
    wide.index.name = "DATE"
    return wide

oecd_series_ids = [
    "OECD/KEI/CPALTT01.USA.ST.M",  # CPI 2015=100, mensuel, s.a.
    "OECD/KEI/LRHUTTTT.USA.ST.M",  # Unemployment %, mensuel, s.a.
]
oecd_data = oecd_kei_to_wide(oecd_series_ids)
oecd_data = oecd_data.reindex(date_index).ffill().bfill()
oecd_data = oecd_data.rename(columns={
    "OECD/KEI/CPALTT01.USA.ST.M": "OECD_CPI_2015idx_USA",
    "OECD/KEI/LRHUTTTT.USA.ST.M": "OECD_Unemp_rate_pct_USA",
})
print("OCDE shape (avant fallback):", oecd_data.shape, "| NA:", int(oecd_data.isna().sum().sum()))
# Out:
# OCDE shape (avant fallback): (5723, 2) | NA: 11446

# %%
# ===========================================================
# 3bis) Fallback OCDE depuis FRED si colonnes vides (0 NaN)
# ===========================================================
def fill_oecd_from_fred(oecd_df, fred_df, date_index):
    o = oecd_df.copy()
    changed = []

    # CPI indice 2015=100 à partir de CPIAUCSL (mensuel)
    if "OECD_CPI_2015idx_USA" in o.columns and o["OECD_CPI_2015idx_USA"].isna().all():
        cpi_m = fred_df["Inflation_CPI"].resample("ME").last()
        base_2015 = cpi_m.loc["2015-01-31":"2015-12-31"].mean()
        o["OECD_CPI_2015idx_USA"] = (cpi_m/base_2015*100).reindex(date_index).ffill().bfill()
        changed.append("OECD_CPI_2015idx_USA ← FRED CPIAUCSL (base 2015=100)")

    # Unemployment % à partir de UNRATE (mensuel)
    if "OECD_Unemp_rate_pct_USA" in o.columns and o["OECD_Unemp_rate_pct_USA"].isna().all():
        un_m = fred_df["Unemployment_Rate"].resample("ME").last()
        o["OECD_Unemp_rate_pct_USA"] = un_m.reindex(date_index).ffill().bfill()
        changed.append("OECD_Unemp_rate_pct_USA ← FRED UNRATE")

    if changed:
        print("OCDE fallback:", changed)
    else:
        print("OCDE fallback: aucun")
    return o

oecd_data = fill_oecd_from_fred(oecd_data, fred_data, date_index)
print("OCDE NA après fallback:", int(oecd_data.isna().sum().sum()))
# Out:
# OCDE fallback: ['OECD_CPI_2015idx_USA ← FRED CPIAUCSL (base 2015=100)', 'OECD_Unemp_rate_pct_USA ← FRED UNRATE']
# OCDE NA après fallback: 0

# %%
oecd_data
# Out:
#             OECD_CPI_2015idx_USA  OECD_Unemp_rate_pct_USA
# 2010-01-01             91.766411                      9.8
# 2010-01-02             91.766411                      9.8
# 2010-01-03             91.766411                      9.8
# 2010-01-04             91.766411                      9.8
# 2010-01-05             91.766411                      9.8
# ...                          ...                      ...
# 2025-08-28            135.919671                      4.2
# 2025-08-29            135.919671                      4.2
# 2025-08-30            135.919671                      4.2
# 2025-08-31            136.439499                      4.3
# 2025-09-01            136.439499                      4.3
#
# [5723 rows x 2 columns]

# %%
fred_data
# Out:
#             Inflation_CPI  Unemployment_Rate  Fed_Funds_Rate   Real_GDP  \
# 2010-01-01        217.488                9.8            0.11  16582.710
# 2010-01-02        217.488                9.8            0.11  16582.710
# 2010-01-03        217.488                9.8            0.11  16582.710
# 2010-01-04        217.488                9.8            0.11  16582.710
# 2010-01-05        217.488                9.8            0.11  16582.710
# ...                   ...                ...             ...        ...
# 2025-08-28        323.364                4.3            4.33  23770.976
# 2025-08-29        323.364                4.3            4.33  23770.976
# 2025-08-30        323.364                4.3            4.33  23770.976
# 2025-08-31        323.364                4.3            4.33  23770.976
# 2025-09-01        324.368                4.4            4.22  23770.976
#
#             Yield_Curve_Spread  Industrial_Production  M2_Money_Supply  \
# 2010-01-01                3.77                89.3426           8477.7
# 2010-01-02                3.77                89.3426           8477.7
# 2010-01-03                3.77                89.3426           8477.7
# 2010-01-04                3.77                89.3426           8477.7
# 2010-01-05                3.70                89.3426           8477.7
# ...                        ...                    ...              ...
# 2025-08-28               -0.04               101.2704          22108.4
# 2025-08-29                0.00               101.2704          22108.4
# 2025-08-30                0.00               101.2704          22108.4
# 2025-08-31                0.00               101.2704          22108.4
# 2025-09-01                0.00               101.2704          22212.5
#
#             Personal_Consumption_Expenditures  Recession_Probability
# 2010-01-01                            10056.1                   0.08
# 2010-01-02                            10056.1                   0.08
# 2010-01-03                            10056.1                   0.08
# 2010-01-04                            10056.1                   0.08
# 2010-01-05                            10056.1                   0.08
# ...                                       ...                    ...
# 2025-08-28                            21111.9                   0.96
# 2025-08-29                            21111.9                   0.96
# 2025-08-30                            21111.9                   0.96
# 2025-08-31                            21111.9                   0.96
# 2025-09-01                            21111.9                   0.96
#
# [5723 rows x 9 columns]

# %%
wb_data
# Out:
#             GDP_Current_USD  Inflation_Annual_Pct  Unemployment_Total_Pct  \
# 2010-01-01     1.504897e+13              1.640043                   9.633
# 2010-01-02     1.504897e+13              1.640043                   9.633
# 2010-01-03     1.504897e+13              1.640043                   9.633
# 2010-01-04     1.504897e+13              1.640043                   9.633
# 2010-01-05     1.504897e+13              1.640043                   9.633
# ...                     ...                   ...                     ...
# 2025-08-28     2.918489e+13              2.949525                   4.106
# 2025-08-29     2.918489e+13              2.949525                   4.106
# 2025-08-30     2.918489e+13              2.949525                   4.106
# 2025-08-31     2.918489e+13              2.949525                   4.106
# 2025-09-01     2.918489e+13              2.949525                   4.106
#
#             Exports_GDP_Pct  Imports_GDP_Pct  Public_Debt_GDP_Pct
# 2010-01-01        12.341355        15.878528            84.964374
# 2010-01-02        12.341355        15.878528            84.964374
# 2010-01-03        12.341355        15.878528            84.964374
# 2010-01-04        12.341355        15.878528            84.964374
# 2010-01-05        12.341355        15.878528            84.964374
# ...                     ...              ...                  ...
# 2025-08-28        10.896875        13.991117           114.755553
# 2025-08-29        10.896875        13.991117           114.755553
# 2025-08-30        10.896875        13.991117           114.755553
# 2025-08-31        10.896875        13.991117           114.755553
# 2025-09-01        10.896875        13.991117           114.755553
#
# [5723 rows x 6 columns]

# %%
oecd_data
# Out:
#             OECD_CPI_2015idx_USA  OECD_Unemp_rate_pct_USA
# 2010-01-01             91.766411                      9.8
# 2010-01-02             91.766411                      9.8
# 2010-01-03             91.766411                      9.8
# 2010-01-04             91.766411                      9.8
# 2010-01-05             91.766411                      9.8
# ...                          ...                      ...
# 2025-08-28            135.919671                      4.2
# 2025-08-29            135.919671                      4.2
# 2025-08-30            135.919671                      4.2
# 2025-08-31            136.439499                      4.3
# 2025-09-01            136.439499                      4.3
#
# [5723 rows x 2 columns]

# %%
# -----------------------------------------------
# 4) MERGE ALL MACRO DATA Sources (+ saving)
# -----------------------------------------------
# Output directory inside project: /data/
OUT = Path("../data")
OUT.mkdir(parents=True, exist_ok=True)

macro_data = (
    fred_data
    .join(wb_data, how="outer")
    .join(oecd_data, how="outer")
    .sort_index()
    .ffill()
    .bfill()
)

print("NA total (macro):", int(macro_data.isna().sum().sum()))

# Save files in /data/
macro_data.to_csv(OUT / "Macro_AllSources.csv")
fred_data.to_csv(OUT / "Macro_FRED.csv")
wb_data.to_csv(OUT / "Macro_WorldBank.csv")
oecd_data.to_csv(OUT / "Macro_OECD.csv")

print(f"Saved macro CSVs to: {OUT.resolve()}")
# Out:
# NA total (macro): 0
# Saved macro CSVs to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data

# %%
#
# 5) Market Data 
#

import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime

# --- PARAMETERS ---
START_DATE = "2010-01-01"
END_DATE   = datetime.today().strftime("%Y-%m-%d")

# Utility function to fetch data
def fetch_data(tickers, start=START_DATE, end=None):
    data = yf.download(tickers, start=start, end=end, progress=False, group_by='ticker', auto_adjust=True)

    # Handle structure depending on number of tickers
    if isinstance(data.columns, pd.MultiIndex):
        # MultiIndex when multiple tickers are requested
        data_close = pd.DataFrame()
        for t in tickers:
            # Try to extract 'Adj Close' or fall back to 'Close'
            if ('Adj Close' in data[t].columns):
                data_close[t] = data[t]['Adj Close']
            elif ('Close' in data[t].columns):
                data_close[t] = data[t]['Close']
            else:
                print(f"⚠️ No valid price data found for {t}")
    else:
        # Single ticker case
        col = 'Adj Close' if 'Adj Close' in data.columns else 'Close'
        data_close = data[[col]].rename(columns={col: tickers[0]})

    data_close.dropna(how='all', inplace=True)
    return data_close

# %%
index_tickers = {
    "S&P500": "^GSPC",
    "NASDAQ": "^IXIC",
    "DowJones": "^DJI",
    "CAC40": "^FCHI",
    "DAX": "^GDAXI",
    "FTSE100": "^FTSE",
    "Nikkei225": "^N225",
    "HangSeng": "^HSI",
    "MSCIWorld": "URTH"
}

indexes = fetch_data(list(index_tickers.values()))
indexes.columns = index_tickers.keys()
print(indexes.head())
print(indexes.tail())
# Out:
#                  S&P500       NASDAQ      DowJones        CAC40          DAX  \
# Date
# 2010-01-04  1132.989990  2308.419922  10583.959961  4013.969971  6048.299805
# 2010-01-05  1136.520020  2308.709961  10572.019531  4012.909912  6031.859863
# 2010-01-06  1137.140015  2301.090088  10573.679688  4017.669922  6034.330078
# 2010-01-07  1141.689941  2300.050049  10606.860352  4024.800049  6019.359863
# 2010-01-08  1144.979980  2317.169922  10618.190430  4045.139893  6037.609863
#
#                 FTSE100     Nikkei225      HangSeng  MSCIWorld
# Date
# 2010-01-04  5500.299805  10654.790039  21823.279297        NaN
# 2010-01-05  5522.500000  10681.830078  22279.580078        NaN
# 2010-01-06  5530.000000  10731.450195  22416.669922        NaN
# 2010-01-07  5526.700195  10681.660156  22269.449219        NaN
# 2010-01-08  5534.200195  10798.320312  22296.750000        NaN
#                  S&P500        NASDAQ      DowJones        CAC40  \
# Date
# 2025-11-20  6538.759766  22078.050781  45752.261719  7981.069824
# 2025-11-21  6602.990234  22273.080078  46245.410156  7982.649902
# 2025-11-24  6705.120117  22872.009766  46448.269531  7959.669922
# 2025-11-25  6765.879883  23025.589844  47112.449219  8025.799805
# 2025-11-26  6812.609863  23214.689453  47427.121094  8096.430176
#
#                      DAX      FTSE100     Nikkei225      HangSeng   MSCIWorld
# Date
# 2025-11-20  23278.849609  9527.700195  49823.941406  25835.570312  177.300003
# 2025-11-21  23091.869141  9539.700195  48625.878906  25220.019531  179.179993
# 2025-11-24  23239.179688  9534.900391           NaN  25716.500000  181.160004
# 2025-11-25  23464.630859  9609.500000  48659.519531  25894.550781  183.220001
# 2025-11-26  23726.220703  9691.580078  49559.070312  25928.080078  184.729996

# %%
# Major Government Bond ETFs and Yield Proxies
bond_tickers = {
    "US10Y": "^TNX",       # 10-Year Treasury Yield (%)
    "US2Y": "^IRX",        # 2-Year Treasury Yield (%)
    "TLT": "TLT",          # 20+ Year Treasury ETF
    "IEF": "IEF",          # 7-10 Year Treasury ETF
    "BND": "BND",          # Total US Bond Market ETF
    "LQD": "LQD"           # Investment Grade Corporate Bond ETF
}

bonds = fetch_data(list(bond_tickers.values()))
bonds.columns = bond_tickers.keys()
bonds.head()
# Out:
#             US10Y   US2Y        TLT        IEF        BND        LQD
# Date
# 2010-01-04  3.841  0.055  57.187607  62.727280  49.618198  58.978424
# 2010-01-05  3.755  0.060  57.556896  63.002724  49.763214  59.260098
# 2010-01-06  3.808  0.045  56.786419  62.748413  49.744286  59.085484
# 2010-01-07  3.822  0.045  56.881931  62.748413  49.706440  59.158707
# 2010-01-08  3.808  0.040  56.856445  62.826138  49.756908  59.288231

# %%
# Leading Stocks by Sector
stock_tickers = {
    "Apple": "AAPL",
    "Microsoft": "MSFT",
    "Google": "GOOGL",
    "Amazon": "AMZN",
    "Meta": "META",
}

stocks = fetch_data(list(stock_tickers.values()))
stocks.columns = stock_tickers.keys()
stocks.head()
# Out:
#                Apple  Microsoft     Google  Amazon  Meta
# Date
# 2010-01-04  6.418382  23.130062  15.576998  6.6950   NaN
# 2010-01-05  6.429481  23.137526  15.508403  6.7345   NaN
# 2010-01-06  6.327210  22.995539  15.117455  6.6125   NaN
# 2010-01-07  6.315514  22.756384  14.765528  6.5000   NaN
# 2010-01-08  6.357502  22.913326  14.962369  6.6760   NaN

# %%
# Merge all classes on Date
market_data = (
    indexes
    .join(bonds, how="outer")
    .join(stocks, how="outer")
)

# Fill and clean
market_data = market_data.sort_index().bfill() #fillna(method="bfill")
market_data.head(10)
market_data.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4138 entries, 2010-01-04 to 2025-11-26
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   S&P500     4138 non-null   float64
#  1   NASDAQ     4138 non-null   float64
#  2   DowJones   4138 non-null   float64
#  3   CAC40      4138 non-null   float64
#  4   DAX        4138 non-null   float64
#  5   FTSE100    4138 non-null   float64
#  6   Nikkei225  4138 non-null   float64
#  7   HangSeng   4138 non-null   float64
#  8   MSCIWorld  4138 non-null   float64
#  9   US10Y      4138 non-null   float64
#  10  US2Y       4138 non-null   float64
#  11  TLT        4138 non-null   float64
#  12  IEF        4138 non-null   float64
#  13  BND        4138 non-null   float64
#  14  LQD        4138 non-null   float64
#  15  Apple      4138 non-null   float64
#  16  Microsoft  4138 non-null   float64
#  17  Google     4138 non-null   float64
#  18  Amazon     4138 non-null   float64
#  19  Meta       4138 non-null   float64
# dtypes: float64(20)
# memory usage: 678.9 KB

# %%
# Save files
market_data.to_csv(OUT / "Market_Prices_All.csv")
print(f"Saved market CSV to: {OUT.resolve()}")
# Out:
# Saved market CSV to: C:\Users\dax_a\Documents\GitHub\ESILV-MLproject-AU-BEJOT\data

# %%
returns = market_data.pct_change(fill_method=None).dropna()
# ---------------------------------------------------------------
# SAVE ALL RETURNS TO CSV
# ---------------------------------------------------------------
returns.to_csv(OUT / "Market_Returns_All.csv")

# %%
# ===============================================================
# MERGING DATASETS
# ===============================================================

from pathlib import Path
# Output directory inside project: /data/
OUT = Path("../data")
OUT.mkdir(parents=True, exist_ok=True)

market = pd.read_csv(OUT / 'Market_Returns_All.csv', index_col=0, parse_dates=True)
macro = pd.read_csv(OUT / 'Macro_AllSources.csv', index_col=0, parse_dates=True)

# %%
# Merge market and macroeconomic data
data = market.join(macro, how='left').ffill()
print("OK Combined dataset shape:", data.shape)
data.tail(5)
data.to_csv(OUT / "Full_dataset_reference.csv")
# Out:
# OK Combined dataset shape: (4137, 37)

# %%
# ===============================================================
# CREATE BINARY TARGET (Direction)
# ===============================================================

# Example index (can change to CAC40 or others)
target_index = "Apple" if "Apple" in data.columns else data.columns[0]

# Create returns and technical indicators
data["Return"] = data[target_index] #.pct_change()
data["Volatility_20d"] = data["Return"].rolling(20).std()
data["MA20"] = data[target_index].rolling(20).mean()
data["MA50"] = data[target_index].rolling(50).mean()
data["Momentum"] = data[target_index] / data[target_index].shift(5) - 1

# Relative Strength Index (RSI)
def compute_RSI(series, window=14):
    delta = series.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window).mean()
    RS = gain / loss
    return 100 - (100 / (1 + RS))

data["RSI"] = compute_RSI(data[target_index])

# Define binary target variable: 1 = Up, 0 = Down
data["Direction"] = (data[target_index].shift(-1) > 0).astype(int)

# Drop rows with NaN
data = data.dropna()
print("OK Final dataset after feature engineering:", data.shape)

data.tail(20)
# Out:
# OK Final dataset after feature engineering: (4085, 44)
#               S&P500    NASDAQ  DowJones     CAC40       DAX   FTSE100  \
# Date
# 2025-10-30 -0.009905 -0.015749 -0.002307 -0.005315 -0.000221  0.000410
# 2025-10-31  0.002618  0.006099  0.000857 -0.004440 -0.006658 -0.004385
# 2025-11-03  0.001721  0.004626 -0.004756 -0.001389  0.007267 -0.001636
# 2025-11-04 -0.011737 -0.020394 -0.005312 -0.005211 -0.007596  0.001402
# 2025-11-05  0.003654  0.006474  0.004795  0.000831  0.004202  0.006392
# 2025-11-06 -0.011178 -0.018971 -0.008427 -0.013557 -0.013128 -0.004224
# 2025-11-07  0.001262 -0.002145  0.001594 -0.001832 -0.006912 -0.005464
# 2025-11-10  0.015401  0.022719  0.008120  0.013249  0.016548  0.010803
# 2025-11-11  0.002075 -0.002502  0.011808  0.012503  0.005345  0.011484
# 2025-11-12  0.000630 -0.002635  0.006820  0.010423  0.012180  0.001192
# 2025-11-13 -0.016557 -0.022904 -0.016529 -0.001062 -0.013939 -0.010463
# 2025-11-14 -0.000502  0.001322 -0.006527 -0.007580 -0.006866 -0.011144
# 2025-11-17 -0.009162 -0.008407 -0.011819 -0.006251 -0.011980 -0.002372
# 2025-11-18 -0.008256 -0.012120 -0.010700 -0.018609 -0.017379 -0.012723
# 2025-11-19  0.003754  0.005857  0.001020 -0.001777 -0.000760 -0.004700
# 2025-11-20 -0.015567 -0.021546 -0.008377  0.003432  0.005005  0.002135
# 2025-11-21  0.009823  0.008834  0.010779  0.000198 -0.008032  0.001259
# 2025-11-24  0.015467  0.026890  0.004387 -0.002879  0.006379 -0.000503
# 2025-11-25  0.009062  0.006715  0.014299  0.008308  0.009701  0.007824
# 2025-11-26  0.006907  0.008213  0.006679  0.008800  0.011148  0.008542
#
#             Nikkei225  HangSeng  MSCIWorld     US10Y  ...  \
# Date                                                  ...
# 2025-10-30   0.000350  0.000000  -0.008378  0.008625  ...
# 2025-10-31   0.021154 -0.014307   0.002058  0.001955  ...
# 2025-11-03  -0.017442  0.009716   0.001784  0.001219  ...
# 2025-11-04   0.000000 -0.007874  -0.012300 -0.004140  ...
# 2025-11-05  -0.024951 -0.000655   0.004534  0.016630  ...
# 2025-11-06   0.013371  0.021225  -0.009461 -0.015396  ...
# 2025-11-07  -0.011935 -0.009215   0.002141  0.000000  ...
# 2025-11-03  0.003503  -1.214216  48.673739          1
# 2025-11-04  0.003387   4.205802  49.347113          1
# 2025-11-05  0.003292  -0.857681  52.061109          0
# 2025-11-06  0.003085  -1.217306  43.751250          0
# 2025-11-07  0.003025   0.269771  35.348703          1
# 2025-11-10  0.003324  -1.931684  51.027615          1
# 2025-11-11  0.003756   4.870486  65.644849          0
# 2025-11-12  0.002865 -18.461073  45.793432          0
# 2025-11-13  0.002717   0.388196  44.259951          0
# 2025-11-14  0.002685  -0.589447  39.235969          0
# 2025-11-17  0.002473  -4.994826  41.353485          0
# 2025-11-18  0.002768  -1.003460  48.932315          1
# 2025-11-19  0.003497  -1.647586  49.160080          0
# 2025-11-20  0.003039   3.523616  48.131565          1
# 2025-11-21  0.003081 -10.947715  57.882130          1
# 2025-11-24  0.003183  -1.897985  54.195393          1
# 2025-11-25  0.003137 -51.917668  51.074674          1
# 2025-11-26  0.003108  -0.499971  51.083853          0
#
# [20 rows x 44 columns]

# %%
data.to_csv(OUT / "Full_dataset_reference.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4085 entries, 2010-03-15 to 2025-11-26
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   S&P500                             4085 non-null   float64
#  1   NASDAQ                             4085 non-null   float64
#  2   DowJones                           4085 non-null   float64
#  3   CAC40                              4085 non-null   float64
#  4   DAX                                4085 non-null   float64
#  5   FTSE100                            4085 non-null   float64
#  6   Nikkei225                          4085 non-null   float64
#  7   HangSeng                           4085 non-null   float64
#  8   MSCIWorld                          4085 non-null   float64
#  9   US10Y                              4085 non-null   float64
#  10  US2Y                               4085 non-null   float64
#  11  TLT                                4085 non-null   float64
#  12  IEF                                4085 non-null   float64
#  13  BND                                4085 non-null   float64
#  14  LQD                                4085 non-null   float64
#  15  Apple                              4085 non-null   float64
#  16  Microsoft                          4085 non-null   float64
#  17  Google                             4085 non-null   float64
#  18  Amazon                             4085 non-null   float64
#  19  Meta                               4085 non-null   float64
#  20  Inflation_CPI                      4085 non-null   float64
#  21  Unemployment_Rate                  4085 non-null   float64
#  22  Fed_Funds_Rate                     4085 non-null   float64
#  23  Real_GDP                           4085 non-null   float64
#  24  Yield_Curve_Spread                 4085 non-null   float64
#  25  Industrial_Production              4085 non-null   float64
#  26  M2_Money_Supply                    4085 non-null   float64
#  27  Personal_Consumption_Expenditures  4085 non-null   float64
#  28  Recession_Probability              4085 non-null   float64
#  29  GDP_Current_USD                    4085 non-null   float64
#  30  Inflation_Annual_Pct               4085 non-null   float64
#  31  Unemployment_Total_Pct             4085 non-null   float64
#  32  Exports_GDP_Pct                    4085 non-null   float64
#  33  Imports_GDP_Pct                    4085 non-null   float64
#  34  Public_Debt_GDP_Pct                4085 non-null   float64
#  35  OECD_CPI_2015idx_USA               4085 non-null   float64
#  36  OECD_Unemp_rate_pct_USA            4085 non-null   float64
#  37  Return                             4085 non-null   float64
#  38  Volatility_20d                     4085 non-null   float64
#  39  MA20                               4085 non-null   float64
#  40  MA50                               4085 non-null   float64
#  41  Momentum                           4085 non-null   float64
#  42  RSI                                4085 non-null   float64
#  43  Direction                          4085 non-null   int32
# dtypes: float64(43), int32(1)
# memory usage: 1.4 MB
